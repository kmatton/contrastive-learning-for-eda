# %% [markdown]
# # WESAD dataset processing

# %%
import os
import pickle
from datetime import datetime as dt
from dateutil import tz
from pathlib import Path
import pytz

import plotly.express as px
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import plotly.io as pio
pio.renderers.default = "browser"

import seaborn as sns
sns.set_theme()
import matplotlib.pyplot as plt
# %matplotlib inline

import numpy as np
import pandas as pd
pd.set_option('display.max_columns', 400)
pd.set_option('display.max_rows', 400)
import neurokit2 as nk

from scipy.fft import fft, fftfreq, ifft
from scipy.signal import firwin, filtfilt, iirnotch, convolve
from scipy.stats import norm

# %% [markdown]
# ## Processing functions

# %%
def load_subject_pickle_data(data_dir, sub_id):
    print(f"working on subject {sub_id}")
    # load subject EDA data and labels
    sub_data = pickle.load(open(os.path.join(data_dir, f"{sub_id}", f"{sub_id}.pkl"), "rb"), encoding='latin1')
    print(f"Loaded data")
    labels = sub_data['label']
    EDA = sub_data['signal']['wrist']['EDA']
    LABEL_SAMPLE_RATE = 700
    EDA_SAMPLE_RATE = 4
    assert labels.shape[0] / LABEL_SAMPLE_RATE == EDA.shape[0] / EDA_SAMPLE_RATE, "labels and EDA are not aligned"
    
    # assign timestamps to EDA data and labels
    # putting random year, day, month, because doesn't matter
    start_dt = dt(2017, 11, 28, 0, 0, 0, 0)
    label_freq = pd.DateOffset(seconds=1/LABEL_SAMPLE_RATE)
    label_times = pd.date_range(start=start_dt, periods=labels.shape[0], freq=label_freq, tz="UTC")
    label_df = pd.DataFrame({"label_sample_timestamp_utc": label_times, "y": list(labels)})
    EDA_freq = pd.DateOffset(seconds=1/EDA_SAMPLE_RATE)
    EDA_times = pd.date_range(start=start_dt, periods=EDA.shape[0], freq=EDA_freq, tz="UTC")
    EDA_df = pd.DataFrame({"eda_sample_timestamp_utc": EDA_times, "eda": list(EDA.flatten())})
    
    print(f"label shape {label_df.shape}")
    print(f"EDA shape {EDA_df.shape}")
    
    # add labels to EDA_df
    EDA_df = pd.merge_asof(EDA_df, label_df, left_on="eda_sample_timestamp_utc", right_on="label_sample_timestamp_utc", direction="nearest")
    
    # drop label timestamp column
    EDA_df.drop(columns="label_sample_timestamp_utc", inplace=True)
    
    # make timestamp index
    EDA_df.set_index("eda_sample_timestamp_utc", inplace=True, drop=False)
    
    return EDA_df

# %%
def create_segments(
    eda_df, 
    segment_length, 
    segment_stride,
):
    """
    segment_lenght and segment_stride should be given in # of samples, NOT seconds    
    NOTE: no adherence checking but I think that's okay
    """
    begin_dts = []
    end_dts = []
    eda_segs = []
    label_segs = []
    left_buffers = []
    right_buffers = []
    for i in range(1, len(eda_df) - segment_length, segment_stride):
        begin_dts.append(eda_df["eda_sample_timestamp_utc"][i])
        end_dts.append(eda_df["eda_sample_timestamp_utc"][i+segment_length-1])
        eda_seg = eda_df["eda"][i:i + segment_length]
        eda_segs.append(list(eda_seg))
        label_segs.append(list(eda_df["y"][i:i+segment_length]))
        # get left buffer
        if i - segment_length >= 0:
            left_buffers.append(list(eda_df["eda"][i-segment_length:i]))
        else:
            left_buffer = np.full_like(eda_seg, np.nan)
            remaining_left_values = eda_df["eda"][:i]
            left_buffer[-remaining_left_values.shape[0]:] = remaining_left_values
            left_buffers.append(left_buffer)
            # left_buffers.append(list(eda_df["eda"][0:segment_length]))
            print(f"using left fill, {i=}")
        
        # get right buffer
        if i + (2*segment_length) < len(eda_df):
            right_buffers.append(list(eda_df["eda"][i+segment_length:i+(2*segment_length)]))
        else:
            right_buffer = np.full_like(eda_seg, np.nan)
            remaining_right_values = eda_df["eda"][i+segment_length:]
            right_buffer[:remaining_right_values.shape[0]] = remaining_right_values
            right_buffers.append(right_buffer)
            print(f"using right fill, {i=}, {len(eda_df)=}")
    
    # create dataframe
    df_dict = {"segment_start_datetime_utc": begin_dts, "segment_end_datetime_utc": end_dts, "y": label_segs}
    eda_segs = np.array(eda_segs)
    eda_segs_dict = {f"x_{i}": eda_segs[:, i] for i in range(eda_segs.shape[1])}
    df_dict.update(eda_segs_dict)
    left_buffers = np.array(left_buffers)
    left_buffer_dict = {f"x_left_buffer_{i}": left_buffers[:, i] for i in range(left_buffers.shape[1])}
    df_dict.update(left_buffer_dict)
    right_buffers = np.array(right_buffers)
    right_buffer_dict = {f"x_right_buffer_{i}": right_buffers[:, i] for i in range(right_buffers.shape[1])}
    df_dict.update(right_buffer_dict)
    eda_segments_df = pd.DataFrame(df_dict)
    return eda_segments_df

# %%
def process_subject_data(
    data_dir, 
    sub_id, 
    output_dir, 
    segment_length=240, 
    segment_stride=1,
    subsample_50_50=False,
):
    
    EDA_df = load_subject_pickle_data(data_dir, sub_id)
    
    # check that all timestamps are included
    all_ts = pd.date_range(
                EDA_df.index.min().astimezone(pytz.utc),
                EDA_df.index.max().astimezone(pytz.utc),
                freq=pd.DateOffset(seconds=0.25),
            )
    assert len(EDA_df) == len(all_ts), f"EDA DF for subject {sub_id} does not include all timestamps"    
    
    # segment data
    EDA_segment_df = create_segments(EDA_df, segment_length, segment_stride)
    
    # map list of labels for each segment to single label (throw out segments that include multiple labels)
    def agg_labels(label_list):
        label_set = set(label_list)
        if len(label_set) != 1:
            return np.NAN
        return label_list[0]
    EDA_segment_df["y"] = EDA_segment_df["y"].apply(lambda x: agg_labels(x))
    
    # get version of EDA with only the desired labels
    EDA_labelled_df = EDA_segment_df[EDA_segment_df["y"].isin([1, 2])]
    print(f"{len(EDA_labelled_df)} examples are stress/no-stress; whole dataset has {len(EDA_segment_df)} examples")
    
    # subsample data to be 50-50 stress/no-stress
    if subsample_50_50:
        pos_df = EDA_labelled_df[EDA_labelled_df["y"] == 2]
        neg_df = EDA_labelled_df[EDA_labelled_df["y"] == 1]
        pos_count = len(pos_df)
        neg_count = len(neg_df)
        print(f"pos count {pos_count}, neg_count {neg_count}")
        remove_count = np.abs(pos_count - neg_count)
        if pos_count > neg_count:
            remove_idx_i = np.random.choice(len(pos_df), size=remove_count, replace=False)
            remove_idx = pos_df.iloc[remove_idx_i].index
        else:
            remove_idx_i = np.random.choice(len(neg_df), size=remove_count, replace=False)
            remove_idx = neg_df.iloc[remove_idx_i].index

        EDA_labelled_df.drop(labels=remove_idx, inplace=True)
        
        # get updated pos/neg counts
        pos_df = EDA_labelled_df[EDA_labelled_df["y"] == 2]
        neg_df = EDA_labelled_df[EDA_labelled_df["y"] == 1]
        pos_count = len(pos_df)
        neg_count = len(neg_df)
        print(f"updated, pos count {pos_count}, neg_count {neg_count}")
    
    # get unlabelled dataset - drop label column from unlabelled df
    EDA_unlabelled_df = EDA_segment_df.drop(columns="y")
    
    # save dataframes -- TODO: drop index???
    if not os.path.exists(os.path.join(output_dir, sub_id)):
        os.makedirs(os.path.join(output_dir, sub_id))
    EDA_labelled_df.to_csv(os.path.join(output_dir, sub_id, "EDA_labelled.csv"))
    EDA_unlabelled_df.to_csv(os.path.join(output_dir, sub_id, "EDA_unlabelled.csv"))
    
    return EDA_labelled_df, EDA_unlabelled_df

# %% [markdown]
# ## Process WESAD data with stride of 1 sample
#
# ### Example with dataset from only 1 participant

# %%
s10_labelled_stride1, s10_unlabelled_stride1 = (
    process_subject_data(
        "../../../biosignal-datasets/WESAD/WESAD/", "S10", "WESAD_TEST",
        segment_length=240, segment_stride=1,
    )
)
# Out:
# working on subject S10
# Loaded data
# label shape (3847200, 2)
# EDA shape (21984, 2)
# using left fill, i=1
# using left fill, i=2
# using left fill, i=3
# using left fill, i=4
# using left fill, i=5
# using left fill, i=6
# using left fill, i=7
# using left fill, i=8
# using left fill, i=9
# using left fill, i=10
# using left fill, i=11
# using left fill, i=12
# using left fill, i=13
# using left fill, i=14
# using left fill, i=15
# using left fill, i=16
# using left fill, i=17
# using left fill, i=18
# using left fill, i=19
# using left fill, i=20
# using left fill, i=21
# using left fill, i=22
# using left fill, i=23
# using left fill, i=24
# using left fill, i=25
# using left fill, i=26
# using left fill, i=27
# using left fill, i=28
# using left fill, i=29
# using left fill, i=30
# using left fill, i=31
# using left fill, i=32
# using left fill, i=33
# using left fill, i=34
# using left fill, i=35
# using left fill, i=36
# using left fill, i=37
# using left fill, i=38
# using left fill, i=39
# using left fill, i=40
# using left fill, i=41
# using left fill, i=42
# using left fill, i=43
# using left fill, i=44
# using left fill, i=45
# using left fill, i=46
# using left fill, i=47
# using left fill, i=48
# using left fill, i=49
# using left fill, i=50
# using left fill, i=51
# using left fill, i=52
# using left fill, i=53
# using left fill, i=54
# using left fill, i=55
# using left fill, i=56
# using left fill, i=57
# using left fill, i=58
# using left fill, i=59
# using left fill, i=60
# using left fill, i=61
# using left fill, i=62
# using left fill, i=63
# using left fill, i=64
# using left fill, i=65
# using left fill, i=66
# using left fill, i=67
# using left fill, i=68
# using left fill, i=69
# using left fill, i=70
# using left fill, i=71
# using left fill, i=72
# using left fill, i=73
# using left fill, i=74
# using left fill, i=75
# using left fill, i=76
# using left fill, i=77
# using left fill, i=78
# using left fill, i=79
# using left fill, i=80
# using left fill, i=81
# using left fill, i=82
# using left fill, i=83
# using left fill, i=84
# using left fill, i=85
# using left fill, i=86
# using left fill, i=87
# using left fill, i=88
# using left fill, i=89
# using left fill, i=90
# using left fill, i=91
# using left fill, i=92
# using left fill, i=93
# using left fill, i=94
# using left fill, i=95
# using left fill, i=96
# using left fill, i=97
# using left fill, i=98
# using left fill, i=99
# using left fill, i=100
# using left fill, i=101
# using left fill, i=102
# using left fill, i=103
# using left fill, i=104
# using left fill, i=105
# using left fill, i=106
# using left fill, i=107
# using left fill, i=108
# using left fill, i=109
# using left fill, i=110
# using left fill, i=111
# using left fill, i=112
# using left fill, i=113
# using left fill, i=114
# using left fill, i=115
# using left fill, i=116
# using left fill, i=117
# using left fill, i=118
# using left fill, i=119
# using left fill, i=120
# using left fill, i=121
# using left fill, i=122
# using left fill, i=123
# using left fill, i=124
# using left fill, i=125
# using left fill, i=126
# using left fill, i=127
# using left fill, i=128
# using left fill, i=129
# using left fill, i=130
# using left fill, i=131
# using left fill, i=132
# using left fill, i=133
# using left fill, i=134
# using left fill, i=135
# using left fill, i=136
# using left fill, i=137
# using left fill, i=138
# using left fill, i=139
# using left fill, i=140
# using left fill, i=141
# using left fill, i=142
# using left fill, i=143
# using left fill, i=144
# using left fill, i=145
# using left fill, i=146
# using left fill, i=147
# using left fill, i=148
# using left fill, i=149
# using left fill, i=150
# using left fill, i=151
# using left fill, i=152
# using left fill, i=153
# using left fill, i=154
# using left fill, i=155
# using left fill, i=156
# using left fill, i=157
# using left fill, i=158
# using left fill, i=159
# using left fill, i=160
# using left fill, i=161
# using left fill, i=162
# using left fill, i=163
# using left fill, i=164
# using left fill, i=165
# using left fill, i=166
# using left fill, i=167
# using left fill, i=168
# using left fill, i=169
# using left fill, i=170
# using left fill, i=171
# using left fill, i=172
# using left fill, i=173
# using left fill, i=174
# using left fill, i=175
# using left fill, i=176
# using left fill, i=177
# using left fill, i=178
# using left fill, i=179
# using left fill, i=180
# using left fill, i=181
# using left fill, i=182
# using left fill, i=183
# using left fill, i=184
# using left fill, i=185
# using left fill, i=186
# using left fill, i=187
# using left fill, i=188
# using left fill, i=189
# using left fill, i=190
# using left fill, i=191
# using left fill, i=192
# using left fill, i=193
# using left fill, i=194
# using left fill, i=195
# using left fill, i=196
# using left fill, i=197
# using left fill, i=198
# using left fill, i=199
# using left fill, i=200
# using left fill, i=201
# using left fill, i=202
# using left fill, i=203
# using left fill, i=204
# using left fill, i=205
# using left fill, i=206
# using left fill, i=207
# using left fill, i=208
# using left fill, i=209
# using left fill, i=210
# using left fill, i=211
# using left fill, i=212
# using left fill, i=213
# using left fill, i=214
# using left fill, i=215
# using left fill, i=216
# using left fill, i=217
# using left fill, i=218
# using left fill, i=219
# using left fill, i=220
# using left fill, i=221
# using left fill, i=222
# using left fill, i=223
# using left fill, i=224
# using left fill, i=225
# using left fill, i=226
# using left fill, i=227
# using left fill, i=228
# using left fill, i=229
# using left fill, i=230
# using left fill, i=231
# using left fill, i=232
# using left fill, i=233
# using left fill, i=234
# using left fill, i=235
# using left fill, i=236
# using left fill, i=237
# using left fill, i=238
# using left fill, i=239
# using right fill, i=21504, len(eda_df)=21984
# using right fill, i=21505, len(eda_df)=21984
# using right fill, i=21506, len(eda_df)=21984
# using right fill, i=21507, len(eda_df)=21984
# using right fill, i=21508, len(eda_df)=21984
# using right fill, i=21509, len(eda_df)=21984
# using right fill, i=21510, len(eda_df)=21984
# using right fill, i=21511, len(eda_df)=21984
# using right fill, i=21512, len(eda_df)=21984
# using right fill, i=21513, len(eda_df)=21984
# using right fill, i=21514, len(eda_df)=21984
# using right fill, i=21515, len(eda_df)=21984
# using right fill, i=21516, len(eda_df)=21984
# using right fill, i=21517, len(eda_df)=21984
# using right fill, i=21518, len(eda_df)=21984
# using right fill, i=21519, len(eda_df)=21984
# using right fill, i=21520, len(eda_df)=21984
# using right fill, i=21521, len(eda_df)=21984
# using right fill, i=21522, len(eda_df)=21984
# using right fill, i=21523, len(eda_df)=21984
# using right fill, i=21524, len(eda_df)=21984
# using right fill, i=21525, len(eda_df)=21984
# using right fill, i=21526, len(eda_df)=21984
# using right fill, i=21527, len(eda_df)=21984
# using right fill, i=21528, len(eda_df)=21984
# using right fill, i=21529, len(eda_df)=21984
# using right fill, i=21530, len(eda_df)=21984
# using right fill, i=21531, len(eda_df)=21984
# using right fill, i=21532, len(eda_df)=21984
# using right fill, i=21533, len(eda_df)=21984
# using right fill, i=21534, len(eda_df)=21984
# using right fill, i=21535, len(eda_df)=21984
# using right fill, i=21536, len(eda_df)=21984
# using right fill, i=21537, len(eda_df)=21984
# using right fill, i=21538, len(eda_df)=21984
# using right fill, i=21539, len(eda_df)=21984
# using right fill, i=21540, len(eda_df)=21984
# using right fill, i=21541, len(eda_df)=21984
# using right fill, i=21542, len(eda_df)=21984
# using right fill, i=21543, len(eda_df)=21984
# using right fill, i=21544, len(eda_df)=21984
# using right fill, i=21545, len(eda_df)=21984
# using right fill, i=21546, len(eda_df)=21984
# using right fill, i=21547, len(eda_df)=21984
# using right fill, i=21548, len(eda_df)=21984
# using right fill, i=21549, len(eda_df)=21984
# using right fill, i=21550, len(eda_df)=21984
# using right fill, i=21551, len(eda_df)=21984
# using right fill, i=21552, len(eda_df)=21984
# using right fill, i=21553, len(eda_df)=21984
# using right fill, i=21554, len(eda_df)=21984
# using right fill, i=21555, len(eda_df)=21984
# using right fill, i=21556, len(eda_df)=21984
# using right fill, i=21557, len(eda_df)=21984
# using right fill, i=21558, len(eda_df)=21984
# using right fill, i=21559, len(eda_df)=21984
# using right fill, i=21560, len(eda_df)=21984
# using right fill, i=21561, len(eda_df)=21984
# using right fill, i=21562, len(eda_df)=21984
# using right fill, i=21563, len(eda_df)=21984
# using right fill, i=21564, len(eda_df)=21984
# using right fill, i=21565, len(eda_df)=21984
# using right fill, i=21566, len(eda_df)=21984
# using right fill, i=21567, len(eda_df)=21984
# using right fill, i=21568, len(eda_df)=21984
# using right fill, i=21569, len(eda_df)=21984
# using right fill, i=21570, len(eda_df)=21984
# using right fill, i=21571, len(eda_df)=21984
# using right fill, i=21572, len(eda_df)=21984
# using right fill, i=21573, len(eda_df)=21984
# using right fill, i=21574, len(eda_df)=21984
# using right fill, i=21575, len(eda_df)=21984
# using right fill, i=21576, len(eda_df)=21984
# using right fill, i=21577, len(eda_df)=21984
# using right fill, i=21578, len(eda_df)=21984
# using right fill, i=21579, len(eda_df)=21984
# using right fill, i=21580, len(eda_df)=21984
# using right fill, i=21581, len(eda_df)=21984
# using right fill, i=21582, len(eda_df)=21984
# using right fill, i=21583, len(eda_df)=21984
# using right fill, i=21584, len(eda_df)=21984
# using right fill, i=21585, len(eda_df)=21984
# using right fill, i=21586, len(eda_df)=21984
# using right fill, i=21587, len(eda_df)=21984
# using right fill, i=21588, len(eda_df)=21984
# using right fill, i=21589, len(eda_df)=21984
# using right fill, i=21590, len(eda_df)=21984
# using right fill, i=21591, len(eda_df)=21984
# using right fill, i=21592, len(eda_df)=21984
# using right fill, i=21593, len(eda_df)=21984
# using right fill, i=21594, len(eda_df)=21984
# using right fill, i=21595, len(eda_df)=21984
# using right fill, i=21596, len(eda_df)=21984
# using right fill, i=21597, len(eda_df)=21984
# using right fill, i=21598, len(eda_df)=21984
# using right fill, i=21599, len(eda_df)=21984
# using right fill, i=21600, len(eda_df)=21984
# using right fill, i=21601, len(eda_df)=21984
# using right fill, i=21602, len(eda_df)=21984
# using right fill, i=21603, len(eda_df)=21984
# using right fill, i=21604, len(eda_df)=21984
# using right fill, i=21605, len(eda_df)=21984
# using right fill, i=21606, len(eda_df)=21984
# using right fill, i=21607, len(eda_df)=21984
# using right fill, i=21608, len(eda_df)=21984
# using right fill, i=21609, len(eda_df)=21984
# using right fill, i=21610, len(eda_df)=21984
# using right fill, i=21611, len(eda_df)=21984
# using right fill, i=21612, len(eda_df)=21984
# using right fill, i=21613, len(eda_df)=21984
# using right fill, i=21614, len(eda_df)=21984
# using right fill, i=21615, len(eda_df)=21984
# using right fill, i=21616, len(eda_df)=21984
# using right fill, i=21617, len(eda_df)=21984
# using right fill, i=21618, len(eda_df)=21984
# using right fill, i=21619, len(eda_df)=21984
# using right fill, i=21620, len(eda_df)=21984
# using right fill, i=21621, len(eda_df)=21984
# using right fill, i=21622, len(eda_df)=21984
# using right fill, i=21623, len(eda_df)=21984
# using right fill, i=21624, len(eda_df)=21984
# using right fill, i=21625, len(eda_df)=21984
# using right fill, i=21626, len(eda_df)=21984
# using right fill, i=21627, len(eda_df)=21984
# using right fill, i=21628, len(eda_df)=21984
# using right fill, i=21629, len(eda_df)=21984
# using right fill, i=21630, len(eda_df)=21984
# using right fill, i=21631, len(eda_df)=21984
# using right fill, i=21632, len(eda_df)=21984
# using right fill, i=21633, len(eda_df)=21984
# using right fill, i=21634, len(eda_df)=21984
# using right fill, i=21635, len(eda_df)=21984
# using right fill, i=21636, len(eda_df)=21984
# using right fill, i=21637, len(eda_df)=21984
# using right fill, i=21638, len(eda_df)=21984
# using right fill, i=21639, len(eda_df)=21984
# using right fill, i=21640, len(eda_df)=21984
# using right fill, i=21641, len(eda_df)=21984
# using right fill, i=21642, len(eda_df)=21984
# using right fill, i=21643, len(eda_df)=21984
# using right fill, i=21644, len(eda_df)=21984
# using right fill, i=21645, len(eda_df)=21984
# using right fill, i=21646, len(eda_df)=21984
# using right fill, i=21647, len(eda_df)=21984
# using right fill, i=21648, len(eda_df)=21984
# using right fill, i=21649, len(eda_df)=21984
# using right fill, i=21650, len(eda_df)=21984
# using right fill, i=21651, len(eda_df)=21984
# using right fill, i=21652, len(eda_df)=21984
# using right fill, i=21653, len(eda_df)=21984
# using right fill, i=21654, len(eda_df)=21984
# using right fill, i=21655, len(eda_df)=21984
# using right fill, i=21656, len(eda_df)=21984
# using right fill, i=21657, len(eda_df)=21984
# using right fill, i=21658, len(eda_df)=21984
# using right fill, i=21659, len(eda_df)=21984
# using right fill, i=21660, len(eda_df)=21984
# using right fill, i=21661, len(eda_df)=21984
# using right fill, i=21662, len(eda_df)=21984
# using right fill, i=21663, len(eda_df)=21984
# using right fill, i=21664, len(eda_df)=21984
# using right fill, i=21665, len(eda_df)=21984
# using right fill, i=21666, len(eda_df)=21984
# using right fill, i=21667, len(eda_df)=21984
# using right fill, i=21668, len(eda_df)=21984
# using right fill, i=21669, len(eda_df)=21984
# using right fill, i=21670, len(eda_df)=21984
# using right fill, i=21671, len(eda_df)=21984
# using right fill, i=21672, len(eda_df)=21984
# using right fill, i=21673, len(eda_df)=21984
# using right fill, i=21674, len(eda_df)=21984
# using right fill, i=21675, len(eda_df)=21984
# using right fill, i=21676, len(eda_df)=21984
# using right fill, i=21677, len(eda_df)=21984
# using right fill, i=21678, len(eda_df)=21984
# using right fill, i=21679, len(eda_df)=21984
# using right fill, i=21680, len(eda_df)=21984
# using right fill, i=21681, len(eda_df)=21984
# using right fill, i=21682, len(eda_df)=21984
# using right fill, i=21683, len(eda_df)=21984
# using right fill, i=21684, len(eda_df)=21984
# using right fill, i=21685, len(eda_df)=21984
# using right fill, i=21686, len(eda_df)=21984
# using right fill, i=21687, len(eda_df)=21984
# using right fill, i=21688, len(eda_df)=21984
# using right fill, i=21689, len(eda_df)=21984
# using right fill, i=21690, len(eda_df)=21984
# using right fill, i=21691, len(eda_df)=21984
# using right fill, i=21692, len(eda_df)=21984
# using right fill, i=21693, len(eda_df)=21984
# using right fill, i=21694, len(eda_df)=21984
# using right fill, i=21695, len(eda_df)=21984
# using right fill, i=21696, len(eda_df)=21984
# using right fill, i=21697, len(eda_df)=21984
# using right fill, i=21698, len(eda_df)=21984
# using right fill, i=21699, len(eda_df)=21984
# using right fill, i=21700, len(eda_df)=21984
# using right fill, i=21701, len(eda_df)=21984
# using right fill, i=21702, len(eda_df)=21984
# using right fill, i=21703, len(eda_df)=21984
# using right fill, i=21704, len(eda_df)=21984
# using right fill, i=21705, len(eda_df)=21984
# using right fill, i=21706, len(eda_df)=21984
# using right fill, i=21707, len(eda_df)=21984
# using right fill, i=21708, len(eda_df)=21984
# using right fill, i=21709, len(eda_df)=21984
# using right fill, i=21710, len(eda_df)=21984
# using right fill, i=21711, len(eda_df)=21984
# using right fill, i=21712, len(eda_df)=21984
# using right fill, i=21713, len(eda_df)=21984
# using right fill, i=21714, len(eda_df)=21984
# using right fill, i=21715, len(eda_df)=21984
# using right fill, i=21716, len(eda_df)=21984
# using right fill, i=21717, len(eda_df)=21984
# using right fill, i=21718, len(eda_df)=21984
# using right fill, i=21719, len(eda_df)=21984
# using right fill, i=21720, len(eda_df)=21984
# using right fill, i=21721, len(eda_df)=21984
# using right fill, i=21722, len(eda_df)=21984
# using right fill, i=21723, len(eda_df)=21984
# using right fill, i=21724, len(eda_df)=21984
# using right fill, i=21725, len(eda_df)=21984
# using right fill, i=21726, len(eda_df)=21984
# using right fill, i=21727, len(eda_df)=21984
# using right fill, i=21728, len(eda_df)=21984
# using right fill, i=21729, len(eda_df)=21984
# using right fill, i=21730, len(eda_df)=21984
# using right fill, i=21731, len(eda_df)=21984
# using right fill, i=21732, len(eda_df)=21984
# using right fill, i=21733, len(eda_df)=21984
# using right fill, i=21734, len(eda_df)=21984
# using right fill, i=21735, len(eda_df)=21984
# using right fill, i=21736, len(eda_df)=21984
# using right fill, i=21737, len(eda_df)=21984
# using right fill, i=21738, len(eda_df)=21984
# using right fill, i=21739, len(eda_df)=21984
# using right fill, i=21740, len(eda_df)=21984
# using right fill, i=21741, len(eda_df)=21984
# using right fill, i=21742, len(eda_df)=21984
# using right fill, i=21743, len(eda_df)=21984
# 7144 examples are stress/no-stress; whole dataset has 21743 examples

# %%
SEGMENT_IX = 50
s10_unlabelled_stride1 = s10_unlabelled_stride1.reset_index(drop=True)
central_segments = s10_unlabelled_stride1.iloc[SEGMENT_IX][[f"x_{i}" for i in range(240)]]
left_buffers = s10_unlabelled_stride1.iloc[SEGMENT_IX][[f"x_left_buffer_{i}" for i in range(240)]]
right_buffers = s10_unlabelled_stride1.iloc[SEGMENT_IX][[f"x_right_buffer_{i}" for i in range(240)]]
plt.plot([i for i in range(240, 480, 1)], central_segments)
plt.plot([i for i in range(0, 240, 1)], left_buffers)
plt.plot([i for i in range(480, 720, 1)], right_buffers)
plt.plot([i for i in range(480, 720, 1)], np.zeros_like(right_buffers))
plt.plot([i for i in range(0, 240, 1)], np.zeros_like(right_buffers))

# %%
SEGMENT_IX = np.random.randint(low=0, high=s10_labelled_stride1.shape[0]-1)
s10_labelled_stride1 = s10_labelled_stride1.reset_index(drop=True)
central_segments = s10_labelled_stride1.iloc[SEGMENT_IX][[f"x_{i}" for i in range(240)]]
left_buffers = s10_labelled_stride1.iloc[SEGMENT_IX][[f"x_left_buffer_{i}" for i in range(240)]]
right_buffers = s10_labelled_stride1.iloc[SEGMENT_IX][[f"x_right_buffer_{i}" for i in range(240)]]
plt.plot([i for i in range(240, 480, 1)], central_segments)
plt.plot([i for i in range(0, 240, 1)], left_buffers)
plt.plot([i for i in range(480, 720, 1)], right_buffers)

# %% [markdown]
# ## Process the full WESAD dataset

# %%
WESAD_DATA_DIR = "../../../biosignal-datasets/WESAD/WESAD/"
WESAD_OUTPUT_DIR = "WESAD_processed_28012023/"

# %%
SEGMENT_LENGTH = 240
SEGMENT_STRIDE = 1

# run on all subjects
for sub_id in os.listdir(WESAD_DATA_DIR):
    if sub_id.startswith("S"):
        process_subject_data(
            WESAD_DATA_DIR, sub_id, WESAD_OUTPUT_DIR, 
            segment_length=SEGMENT_LENGTH, segment_stride=SEGMENT_STRIDE,
        )
# Out:
# working on subject S5
# Loaded data
# label shape (4380600, 2)
# EDA shape (25032, 2)
# using left fill, i=1
# using left fill, i=2
# using left fill, i=3
# using left fill, i=4
# using left fill, i=5
# using left fill, i=6
# using left fill, i=7
# using left fill, i=8
# using left fill, i=9
# using left fill, i=10
# using left fill, i=11
# using left fill, i=12
# using left fill, i=13
# using left fill, i=14
# using left fill, i=15
# using left fill, i=16
# using left fill, i=17
# using left fill, i=18
# using left fill, i=19
# using left fill, i=20
# using left fill, i=21
# using left fill, i=22
# using left fill, i=23
# using left fill, i=24
# using left fill, i=25
# using left fill, i=26
# using left fill, i=27
# using left fill, i=28
# using left fill, i=29
# using left fill, i=30
# using left fill, i=31
# using left fill, i=32
# using left fill, i=33
# using left fill, i=34
# using left fill, i=35
# using left fill, i=36
# using left fill, i=37
# using left fill, i=38
# using left fill, i=39
# using left fill, i=40
# using left fill, i=41
# using left fill, i=42
# using left fill, i=43
# using left fill, i=44
# using left fill, i=45
# using left fill, i=46
# using left fill, i=47
# using left fill, i=48
# using left fill, i=49
# using left fill, i=50
# using left fill, i=51
# using left fill, i=52
# using left fill, i=53
# using left fill, i=54
# using left fill, i=55
# using left fill, i=56
# using left fill, i=57
# using left fill, i=58
# using left fill, i=59
# using left fill, i=60
# using left fill, i=61
# using left fill, i=62
# using left fill, i=63
# using left fill, i=64
# using left fill, i=65
# using left fill, i=66
# using left fill, i=67
# using left fill, i=68
# using left fill, i=69
# using left fill, i=70
# using left fill, i=71
# using left fill, i=72
# using left fill, i=73
# using left fill, i=74
# using left fill, i=75
# using left fill, i=76
# using left fill, i=77
# using left fill, i=78
# using left fill, i=79
# using left fill, i=80
# using left fill, i=81
# using left fill, i=82
# using left fill, i=83
# using left fill, i=84
# using left fill, i=85
# using left fill, i=86
# using left fill, i=87
# using left fill, i=88
# using left fill, i=89
# using left fill, i=90
# using left fill, i=91
# using left fill, i=92
# using left fill, i=93
# using left fill, i=94
# using left fill, i=95
# using left fill, i=96
# using left fill, i=97
# using left fill, i=98
# using left fill, i=99
# using left fill, i=100
# using left fill, i=101
# using left fill, i=102
# using left fill, i=103
# using left fill, i=104
# using left fill, i=105
# using left fill, i=106
# using left fill, i=107
# using left fill, i=108
# using left fill, i=109
# using left fill, i=110
# using left fill, i=111
# using left fill, i=112
# using left fill, i=113
# using left fill, i=114
# using left fill, i=115
# using left fill, i=116
# using left fill, i=117
# using left fill, i=118
# using left fill, i=119
# using left fill, i=120
# using left fill, i=121
# using left fill, i=122
# using left fill, i=123
# using left fill, i=124
# using left fill, i=125
# using left fill, i=126
# using left fill, i=127
# using left fill, i=128
# using left fill, i=129
# using left fill, i=130
# using left fill, i=131
# using left fill, i=132
# using left fill, i=133
# using left fill, i=134
# using left fill, i=135
# using left fill, i=136
# using left fill, i=137
# using left fill, i=138
# using left fill, i=139
# using left fill, i=140
# using left fill, i=141
# using left fill, i=142
# using left fill, i=143
# using left fill, i=144
# using left fill, i=145
# using left fill, i=146
# using left fill, i=147
# using left fill, i=148
# using left fill, i=149
# using left fill, i=150
# using left fill, i=151
# using left fill, i=152
# using left fill, i=153
# using left fill, i=154
# using left fill, i=155
# using left fill, i=156
# using left fill, i=157
# using left fill, i=158
# using left fill, i=159
# using left fill, i=160
# using left fill, i=161
# using left fill, i=162
# using left fill, i=163
# using left fill, i=164
# using left fill, i=165
# using left fill, i=166
# using left fill, i=167
# using left fill, i=168
# using left fill, i=169
# using left fill, i=170
# using left fill, i=171
# using left fill, i=172
# using left fill, i=173
# using left fill, i=174
# using left fill, i=175
# using left fill, i=176
# using left fill, i=177
# using left fill, i=178
# using left fill, i=179
# using left fill, i=180
# using left fill, i=181
# using left fill, i=182
# using left fill, i=183
# using left fill, i=184
# using left fill, i=185
# using left fill, i=186
# using left fill, i=187
# using left fill, i=188
# using left fill, i=189
# using left fill, i=190
# using left fill, i=191
# using left fill, i=192
# using left fill, i=193
# using left fill, i=194
# using left fill, i=195
# using left fill, i=196
# using left fill, i=197
# using left fill, i=198
# using left fill, i=199
# using left fill, i=200
# using left fill, i=201
# using left fill, i=202
# using left fill, i=203
# using left fill, i=204
# using left fill, i=205
# using left fill, i=206
# using left fill, i=207
# using left fill, i=208
# using left fill, i=209
# using left fill, i=210
# using left fill, i=211
# using left fill, i=212
# using left fill, i=213
# using left fill, i=214
# using left fill, i=215
# using left fill, i=216
# using left fill, i=217
# using left fill, i=218
# using left fill, i=219
# using left fill, i=220
# using left fill, i=221
# using left fill, i=222
# using left fill, i=223
# using left fill, i=224
# using left fill, i=225
# using left fill, i=226
# using left fill, i=227
# using left fill, i=228
# using left fill, i=229
# using left fill, i=230
# using left fill, i=231
# using left fill, i=232
# using left fill, i=233
# using left fill, i=234
# using left fill, i=235
# using left fill, i=236
# using left fill, i=237
# using left fill, i=238
# using left fill, i=239
# using right fill, i=24552, len(eda_df)=25032
# using right fill, i=24553, len(eda_df)=25032
# using right fill, i=24554, len(eda_df)=25032
# using right fill, i=24555, len(eda_df)=25032
# using right fill, i=24556, len(eda_df)=25032
# using right fill, i=24557, len(eda_df)=25032
# using right fill, i=24558, len(eda_df)=25032
# using right fill, i=24559, len(eda_df)=25032
# using right fill, i=24560, len(eda_df)=25032
# using right fill, i=24561, len(eda_df)=25032
# using right fill, i=24562, len(eda_df)=25032
# using right fill, i=24563, len(eda_df)=25032
# using right fill, i=24564, len(eda_df)=25032
# using right fill, i=24565, len(eda_df)=25032
# using right fill, i=24566, len(eda_df)=25032
# using right fill, i=24567, len(eda_df)=25032
# using right fill, i=24568, len(eda_df)=25032
# using right fill, i=24569, len(eda_df)=25032
# using right fill, i=24570, len(eda_df)=25032
# using right fill, i=24571, len(eda_df)=25032
# using right fill, i=24572, len(eda_df)=25032
# using right fill, i=24573, len(eda_df)=25032
# using right fill, i=24574, len(eda_df)=25032
# using right fill, i=24575, len(eda_df)=25032
# using right fill, i=24576, len(eda_df)=25032
# using right fill, i=24577, len(eda_df)=25032
# using right fill, i=24578, len(eda_df)=25032
# using right fill, i=24579, len(eda_df)=25032
# using right fill, i=24580, len(eda_df)=25032
# using right fill, i=24581, len(eda_df)=25032
# using right fill, i=24582, len(eda_df)=25032
# using right fill, i=24583, len(eda_df)=25032
# using right fill, i=24584, len(eda_df)=25032
# using right fill, i=24585, len(eda_df)=25032
# using right fill, i=24586, len(eda_df)=25032
# using right fill, i=24587, len(eda_df)=25032
# using right fill, i=24588, len(eda_df)=25032
# using right fill, i=24589, len(eda_df)=25032
# using right fill, i=24590, len(eda_df)=25032
# using right fill, i=24591, len(eda_df)=25032
# using right fill, i=24592, len(eda_df)=25032
# using right fill, i=24593, len(eda_df)=25032
# using right fill, i=24594, len(eda_df)=25032
# using right fill, i=24595, len(eda_df)=25032
# using right fill, i=24596, len(eda_df)=25032
# using right fill, i=24597, len(eda_df)=25032
# using right fill, i=24598, len(eda_df)=25032
# using right fill, i=24599, len(eda_df)=25032
# using right fill, i=24600, len(eda_df)=25032
# using right fill, i=24601, len(eda_df)=25032
# using right fill, i=24602, len(eda_df)=25032
# using right fill, i=24603, len(eda_df)=25032
# using right fill, i=24604, len(eda_df)=25032
# using right fill, i=24605, len(eda_df)=25032
# using right fill, i=24606, len(eda_df)=25032
# using right fill, i=24607, len(eda_df)=25032
# using right fill, i=24608, len(eda_df)=25032
# using right fill, i=24609, len(eda_df)=25032
# using right fill, i=24610, len(eda_df)=25032
# using right fill, i=24611, len(eda_df)=25032
# using right fill, i=24612, len(eda_df)=25032
# using right fill, i=24613, len(eda_df)=25032
# using right fill, i=24614, len(eda_df)=25032
# using right fill, i=24615, len(eda_df)=25032
# using right fill, i=24616, len(eda_df)=25032
# using right fill, i=24617, len(eda_df)=25032
# using right fill, i=24618, len(eda_df)=25032
# using right fill, i=24619, len(eda_df)=25032
# using right fill, i=24620, len(eda_df)=25032
# using right fill, i=24621, len(eda_df)=25032
# using right fill, i=24622, len(eda_df)=25032
# using right fill, i=24623, len(eda_df)=25032
# using right fill, i=24624, len(eda_df)=25032
# using right fill, i=24625, len(eda_df)=25032
# using right fill, i=24626, len(eda_df)=25032
# using right fill, i=24627, len(eda_df)=25032
# using right fill, i=24628, len(eda_df)=25032
# using right fill, i=24629, len(eda_df)=25032
# using right fill, i=24630, len(eda_df)=25032
# using right fill, i=24631, len(eda_df)=25032
# using right fill, i=24632, len(eda_df)=25032
# using right fill, i=24633, len(eda_df)=25032
# using right fill, i=24634, len(eda_df)=25032
# using right fill, i=24635, len(eda_df)=25032
# using right fill, i=24636, len(eda_df)=25032
# using right fill, i=24637, len(eda_df)=25032
# using right fill, i=24638, len(eda_df)=25032
# using right fill, i=24639, len(eda_df)=25032
# using right fill, i=24640, len(eda_df)=25032
# using right fill, i=24641, len(eda_df)=25032
# using right fill, i=24642, len(eda_df)=25032
# using right fill, i=24643, len(eda_df)=25032
# using right fill, i=24644, len(eda_df)=25032
# using right fill, i=24645, len(eda_df)=25032
# using right fill, i=24646, len(eda_df)=25032
# using right fill, i=24647, len(eda_df)=25032
# using right fill, i=24648, len(eda_df)=25032
# using right fill, i=24649, len(eda_df)=25032
# using right fill, i=24650, len(eda_df)=25032
# using right fill, i=24651, len(eda_df)=25032
# using right fill, i=24652, len(eda_df)=25032
# using right fill, i=24653, len(eda_df)=25032
# using right fill, i=24654, len(eda_df)=25032
# using right fill, i=24655, len(eda_df)=25032
# using right fill, i=24656, len(eda_df)=25032
# using right fill, i=24657, len(eda_df)=25032
# using right fill, i=24658, len(eda_df)=25032
# using right fill, i=24659, len(eda_df)=25032
# using right fill, i=24660, len(eda_df)=25032
# using right fill, i=24661, len(eda_df)=25032
# using right fill, i=24662, len(eda_df)=25032
# using right fill, i=24663, len(eda_df)=25032
# using right fill, i=24664, len(eda_df)=25032
# using right fill, i=24665, len(eda_df)=25032
# using right fill, i=24666, len(eda_df)=25032
# using right fill, i=24667, len(eda_df)=25032
# using right fill, i=24668, len(eda_df)=25032
# using right fill, i=24669, len(eda_df)=25032
# using right fill, i=24670, len(eda_df)=25032
# using right fill, i=24671, len(eda_df)=25032
# using right fill, i=24672, len(eda_df)=25032
# using right fill, i=24673, len(eda_df)=25032
# using right fill, i=24674, len(eda_df)=25032
# using right fill, i=24675, len(eda_df)=25032
# using right fill, i=24676, len(eda_df)=25032
# using right fill, i=24677, len(eda_df)=25032
# using right fill, i=24678, len(eda_df)=25032
# using right fill, i=24679, len(eda_df)=25032
# using right fill, i=24680, len(eda_df)=25032
# using right fill, i=24681, len(eda_df)=25032
# using right fill, i=24682, len(eda_df)=25032
# using right fill, i=24683, len(eda_df)=25032
# using right fill, i=24684, len(eda_df)=25032
# using right fill, i=24685, len(eda_df)=25032
# using right fill, i=24686, len(eda_df)=25032
# using right fill, i=24687, len(eda_df)=25032
# using right fill, i=24688, len(eda_df)=25032
# using right fill, i=24689, len(eda_df)=25032
# using right fill, i=24690, len(eda_df)=25032
# using right fill, i=24691, len(eda_df)=25032
# using right fill, i=24692, len(eda_df)=25032
# using right fill, i=24693, len(eda_df)=25032
# using right fill, i=24694, len(eda_df)=25032
# using right fill, i=24695, len(eda_df)=25032
# using right fill, i=24696, len(eda_df)=25032
# using right fill, i=24697, len(eda_df)=25032
# using right fill, i=24698, len(eda_df)=25032
# using right fill, i=24699, len(eda_df)=25032
# using right fill, i=24700, len(eda_df)=25032
# using right fill, i=24701, len(eda_df)=25032
# using right fill, i=24702, len(eda_df)=25032
# using right fill, i=24703, len(eda_df)=25032
# using right fill, i=24704, len(eda_df)=25032
# using right fill, i=24705, len(eda_df)=25032
# using right fill, i=24706, len(eda_df)=25032
# using right fill, i=24707, len(eda_df)=25032
# using right fill, i=24708, len(eda_df)=25032
# using right fill, i=24709, len(eda_df)=25032
# using right fill, i=24710, len(eda_df)=25032
# using right fill, i=24711, len(eda_df)=25032
# using right fill, i=24712, len(eda_df)=25032
# using right fill, i=24713, len(eda_df)=25032
# using right fill, i=24714, len(eda_df)=25032
# using right fill, i=24715, len(eda_df)=25032
# using right fill, i=24716, len(eda_df)=25032
# using right fill, i=24717, len(eda_df)=25032
# using right fill, i=24718, len(eda_df)=25032
# using right fill, i=24719, len(eda_df)=25032
# using right fill, i=24720, len(eda_df)=25032
# using right fill, i=24721, len(eda_df)=25032
# using right fill, i=24722, len(eda_df)=25032
# using right fill, i=24723, len(eda_df)=25032
# using right fill, i=24724, len(eda_df)=25032
# using right fill, i=24725, len(eda_df)=25032
# using right fill, i=24726, len(eda_df)=25032
# using right fill, i=24727, len(eda_df)=25032
# using right fill, i=24728, len(eda_df)=25032
# using right fill, i=24729, len(eda_df)=25032
# using right fill, i=24730, len(eda_df)=25032
# using right fill, i=24731, len(eda_df)=25032
# using right fill, i=24732, len(eda_df)=25032
# using right fill, i=24733, len(eda_df)=25032
# using right fill, i=24734, len(eda_df)=25032
# using right fill, i=24735, len(eda_df)=25032
# using right fill, i=24736, len(eda_df)=25032
# using right fill, i=24737, len(eda_df)=25032
# using right fill, i=24738, len(eda_df)=25032
# using right fill, i=24739, len(eda_df)=25032
# using right fill, i=24740, len(eda_df)=25032
# using right fill, i=24741, len(eda_df)=25032
# using right fill, i=24742, len(eda_df)=25032
# using right fill, i=24743, len(eda_df)=25032
# using right fill, i=24744, len(eda_df)=25032
# using right fill, i=24745, len(eda_df)=25032
# using right fill, i=24746, len(eda_df)=25032
# using right fill, i=24747, len(eda_df)=25032
# using right fill, i=24748, len(eda_df)=25032
# using right fill, i=24749, len(eda_df)=25032
# using right fill, i=24750, len(eda_df)=25032
# using right fill, i=24751, len(eda_df)=25032
# using right fill, i=24752, len(eda_df)=25032
# using right fill, i=24753, len(eda_df)=25032
# using right fill, i=24754, len(eda_df)=25032
# using right fill, i=24755, len(eda_df)=25032
# using right fill, i=24756, len(eda_df)=25032
# using right fill, i=24757, len(eda_df)=25032
# using right fill, i=24758, len(eda_df)=25032
# using right fill, i=24759, len(eda_df)=25032
# using right fill, i=24760, len(eda_df)=25032
# using right fill, i=24761, len(eda_df)=25032
# using right fill, i=24762, len(eda_df)=25032
# using right fill, i=24763, len(eda_df)=25032
# using right fill, i=24764, len(eda_df)=25032
# using right fill, i=24765, len(eda_df)=25032
# using right fill, i=24766, len(eda_df)=25032
# using right fill, i=24767, len(eda_df)=25032
# using right fill, i=24768, len(eda_df)=25032
# using right fill, i=24769, len(eda_df)=25032
# using right fill, i=24770, len(eda_df)=25032
# using right fill, i=24771, len(eda_df)=25032
# using right fill, i=24772, len(eda_df)=25032
# using right fill, i=24773, len(eda_df)=25032
# using right fill, i=24774, len(eda_df)=25032
# using right fill, i=24775, len(eda_df)=25032
# using right fill, i=24776, len(eda_df)=25032
# using right fill, i=24777, len(eda_df)=25032
# using right fill, i=24778, len(eda_df)=25032
# using right fill, i=24779, len(eda_df)=25032
# using right fill, i=24780, len(eda_df)=25032
# using right fill, i=24781, len(eda_df)=25032
# using right fill, i=24782, len(eda_df)=25032
# using right fill, i=24783, len(eda_df)=25032
# using right fill, i=24784, len(eda_df)=25032
# using right fill, i=24785, len(eda_df)=25032
# using right fill, i=24786, len(eda_df)=25032
# using right fill, i=24787, len(eda_df)=25032
# using right fill, i=24788, len(eda_df)=25032
# using right fill, i=24789, len(eda_df)=25032
# using right fill, i=24790, len(eda_df)=25032
# using right fill, i=24791, len(eda_df)=25032
# 6897 examples are stress/no-stress; whole dataset has 24791 examples
# working on subject S2
# Loaded data
# label shape (4255300, 2)
# EDA shape (24316, 2)
# using left fill, i=1
# using left fill, i=2
# using left fill, i=3
# using left fill, i=4
# using left fill, i=5
# using left fill, i=6
# using left fill, i=7
# using left fill, i=8
# using left fill, i=9
# using left fill, i=10
# using left fill, i=11
# using left fill, i=12
# using left fill, i=13
# using left fill, i=14
# using left fill, i=15
# using left fill, i=16
# using left fill, i=17
# using left fill, i=18
# using left fill, i=19
# using left fill, i=20
# using left fill, i=21
# using left fill, i=22
# using left fill, i=23
# using left fill, i=24
# using left fill, i=25
# using left fill, i=26
# using left fill, i=27
# using left fill, i=28
# using left fill, i=29
# using left fill, i=30
# using left fill, i=31
# using left fill, i=32
# using left fill, i=33
# using left fill, i=34
# using left fill, i=35
# using left fill, i=36
# using left fill, i=37
# using left fill, i=38
# using left fill, i=39
# using left fill, i=40
# using left fill, i=41
# using left fill, i=42
# using left fill, i=43
# using left fill, i=44
# using left fill, i=45
# using left fill, i=46
# using left fill, i=47
# using left fill, i=48
# using left fill, i=49
# using left fill, i=50
# using left fill, i=51
# using left fill, i=52
# using left fill, i=53
# using left fill, i=54
# using left fill, i=55
# using left fill, i=56
# using left fill, i=57
# using left fill, i=58
# using left fill, i=59
# using left fill, i=60
# using left fill, i=61
# using left fill, i=62
# using left fill, i=63
# using left fill, i=64
# using left fill, i=65
# using left fill, i=66
# using left fill, i=67
# using left fill, i=68
# using left fill, i=69
# using left fill, i=70
# using left fill, i=71
# using left fill, i=72
# using left fill, i=73
# using left fill, i=74
# using left fill, i=75
# using left fill, i=76
# using left fill, i=77
# using left fill, i=78
# using left fill, i=79
# using left fill, i=80
# using left fill, i=81
# using left fill, i=82
# using left fill, i=83
# using left fill, i=84
# using left fill, i=85
# using left fill, i=86
# using left fill, i=87
# using left fill, i=88
# using left fill, i=89
# using left fill, i=90
# using left fill, i=91
# using left fill, i=92
# using left fill, i=93
# using left fill, i=94
# using left fill, i=95
# using left fill, i=96
# using left fill, i=97
# using left fill, i=98
# using left fill, i=99
# using left fill, i=100
# using left fill, i=101
# using left fill, i=102
# using left fill, i=103
# using left fill, i=104
# using left fill, i=105
# using left fill, i=106
# using left fill, i=107
# using left fill, i=108
# using left fill, i=109
# using left fill, i=110
# using left fill, i=111
# using left fill, i=112
# using left fill, i=113
# using left fill, i=114
# using left fill, i=115
# using left fill, i=116
# using left fill, i=117
# using left fill, i=118
# using left fill, i=119
# using left fill, i=120
# using left fill, i=121
# using left fill, i=122
# using left fill, i=123
# using left fill, i=124
# using left fill, i=125
# using left fill, i=126
# using left fill, i=127
# using left fill, i=128
# using left fill, i=129
# using left fill, i=130
# using left fill, i=131
# using left fill, i=132
# using left fill, i=133
# using left fill, i=134
# using left fill, i=135
# using left fill, i=136
# using left fill, i=137
# using left fill, i=138
# using left fill, i=139
# using left fill, i=140
# using left fill, i=141
# using left fill, i=142
# using left fill, i=143
# using left fill, i=144
# using left fill, i=145
# using left fill, i=146
# using left fill, i=147
# using left fill, i=148
# using left fill, i=149
# using left fill, i=150
# using left fill, i=151
# using left fill, i=152
# using left fill, i=153
# using left fill, i=154
# using left fill, i=155
# using left fill, i=156
# using left fill, i=157
# using left fill, i=158
# using left fill, i=159
# using left fill, i=160
# using left fill, i=161
# using left fill, i=162
# using left fill, i=163
# using left fill, i=164
# using left fill, i=165
# using left fill, i=166
# using left fill, i=167
# using left fill, i=168
# using left fill, i=169
# using left fill, i=170
# using left fill, i=171
# using left fill, i=172
# using left fill, i=173
# using left fill, i=174
# using left fill, i=175
# using left fill, i=176
# using left fill, i=177
# using left fill, i=178
# using left fill, i=179
# using left fill, i=180
# using left fill, i=181
# using left fill, i=182
# using left fill, i=183
# using left fill, i=184
# using left fill, i=185
# using left fill, i=186
# using left fill, i=187
# using left fill, i=188
# using left fill, i=189
# using left fill, i=190
# using left fill, i=191
# using left fill, i=192
# using left fill, i=193
# using left fill, i=194
# using left fill, i=195
# using left fill, i=196
# using left fill, i=197
# using left fill, i=198
# using left fill, i=199
# using left fill, i=200
# using left fill, i=201
# using left fill, i=202
# using left fill, i=203
# using left fill, i=204
# using left fill, i=205
# using left fill, i=206
# using left fill, i=207
# using left fill, i=208
# using left fill, i=209
# using left fill, i=210
# using left fill, i=211
# using left fill, i=212
# using left fill, i=213
# using left fill, i=214
# using left fill, i=215
# using left fill, i=216
# using left fill, i=217
# using left fill, i=218
# using left fill, i=219
# using left fill, i=220
# using left fill, i=221
# using left fill, i=222
# using left fill, i=223
# using left fill, i=224
# using left fill, i=225
# using left fill, i=226
# using left fill, i=227
# using left fill, i=228
# using left fill, i=229
# using left fill, i=230
# using left fill, i=231
# using left fill, i=232
# using left fill, i=233
# using left fill, i=234
# using left fill, i=235
# using left fill, i=236
# using left fill, i=237
# using left fill, i=238
# using left fill, i=239
# using right fill, i=23836, len(eda_df)=24316
# using right fill, i=23837, len(eda_df)=24316
# using right fill, i=23838, len(eda_df)=24316
# using right fill, i=23839, len(eda_df)=24316
# using right fill, i=23840, len(eda_df)=24316
# using right fill, i=23841, len(eda_df)=24316
# using right fill, i=23842, len(eda_df)=24316
# using right fill, i=23843, len(eda_df)=24316
# using right fill, i=23844, len(eda_df)=24316
# using right fill, i=23845, len(eda_df)=24316
# using right fill, i=23846, len(eda_df)=24316
# using right fill, i=23847, len(eda_df)=24316
# using right fill, i=23848, len(eda_df)=24316
# using right fill, i=23849, len(eda_df)=24316
# using right fill, i=23850, len(eda_df)=24316
# using right fill, i=23851, len(eda_df)=24316
# using right fill, i=23852, len(eda_df)=24316
# using right fill, i=23853, len(eda_df)=24316
# using right fill, i=23854, len(eda_df)=24316
# using right fill, i=23855, len(eda_df)=24316
# using right fill, i=23856, len(eda_df)=24316
# using right fill, i=23857, len(eda_df)=24316
# using right fill, i=23858, len(eda_df)=24316
# using right fill, i=23859, len(eda_df)=24316
# using right fill, i=23860, len(eda_df)=24316
# using right fill, i=23861, len(eda_df)=24316
# using right fill, i=23862, len(eda_df)=24316
# using right fill, i=23863, len(eda_df)=24316
# using right fill, i=23864, len(eda_df)=24316
# using right fill, i=23865, len(eda_df)=24316
# using right fill, i=23866, len(eda_df)=24316
# using right fill, i=23867, len(eda_df)=24316
# using right fill, i=23868, len(eda_df)=24316
# using right fill, i=23869, len(eda_df)=24316
# using right fill, i=23870, len(eda_df)=24316
# using right fill, i=23871, len(eda_df)=24316
# using right fill, i=23872, len(eda_df)=24316
# using right fill, i=23873, len(eda_df)=24316
# using right fill, i=23874, len(eda_df)=24316
# using right fill, i=23875, len(eda_df)=24316
# using right fill, i=23876, len(eda_df)=24316
# using right fill, i=23877, len(eda_df)=24316
# using right fill, i=23878, len(eda_df)=24316
# using right fill, i=23879, len(eda_df)=24316
# using right fill, i=23880, len(eda_df)=24316
# using right fill, i=23881, len(eda_df)=24316
# using right fill, i=23882, len(eda_df)=24316
# using right fill, i=23883, len(eda_df)=24316
# using right fill, i=23884, len(eda_df)=24316
# using right fill, i=23885, len(eda_df)=24316
# using right fill, i=23886, len(eda_df)=24316
# using right fill, i=23887, len(eda_df)=24316
# using right fill, i=23888, len(eda_df)=24316
# using right fill, i=23889, len(eda_df)=24316
# using right fill, i=23890, len(eda_df)=24316
# using right fill, i=23891, len(eda_df)=24316
# using right fill, i=23892, len(eda_df)=24316
# using right fill, i=23893, len(eda_df)=24316
# using right fill, i=23894, len(eda_df)=24316
# using right fill, i=23895, len(eda_df)=24316
# using right fill, i=23896, len(eda_df)=24316
# using right fill, i=23897, len(eda_df)=24316
# using right fill, i=23898, len(eda_df)=24316
# using right fill, i=23899, len(eda_df)=24316
# using right fill, i=23900, len(eda_df)=24316
# using right fill, i=23901, len(eda_df)=24316
# using right fill, i=23902, len(eda_df)=24316
# using right fill, i=23903, len(eda_df)=24316
# using right fill, i=23904, len(eda_df)=24316
# using right fill, i=23905, len(eda_df)=24316
# using right fill, i=23906, len(eda_df)=24316
# using right fill, i=23907, len(eda_df)=24316
# using right fill, i=23908, len(eda_df)=24316
# using right fill, i=23909, len(eda_df)=24316
# using right fill, i=23910, len(eda_df)=24316
# using right fill, i=23911, len(eda_df)=24316
# using right fill, i=23912, len(eda_df)=24316
# using right fill, i=23913, len(eda_df)=24316
# using right fill, i=23914, len(eda_df)=24316
# using right fill, i=23915, len(eda_df)=24316
# using right fill, i=23916, len(eda_df)=24316
# using right fill, i=23917, len(eda_df)=24316
# using right fill, i=23918, len(eda_df)=24316
# using right fill, i=23919, len(eda_df)=24316
# using right fill, i=23920, len(eda_df)=24316
# using right fill, i=23921, len(eda_df)=24316
# using right fill, i=23922, len(eda_df)=24316
# using right fill, i=23923, len(eda_df)=24316
# using right fill, i=23924, len(eda_df)=24316
# using right fill, i=23925, len(eda_df)=24316
# using right fill, i=23926, len(eda_df)=24316
# using right fill, i=23927, len(eda_df)=24316
# using right fill, i=23928, len(eda_df)=24316
# using right fill, i=23929, len(eda_df)=24316
# using right fill, i=23930, len(eda_df)=24316
# using right fill, i=23931, len(eda_df)=24316
# using right fill, i=23932, len(eda_df)=24316
# using right fill, i=23933, len(eda_df)=24316
# using right fill, i=23934, len(eda_df)=24316
# using right fill, i=23935, len(eda_df)=24316
# using right fill, i=23936, len(eda_df)=24316
# using right fill, i=23937, len(eda_df)=24316
# using right fill, i=23938, len(eda_df)=24316
# using right fill, i=23939, len(eda_df)=24316
# using right fill, i=23940, len(eda_df)=24316
# using right fill, i=23941, len(eda_df)=24316
# using right fill, i=23942, len(eda_df)=24316
# using right fill, i=23943, len(eda_df)=24316
# using right fill, i=23944, len(eda_df)=24316
# using right fill, i=23945, len(eda_df)=24316
# using right fill, i=23946, len(eda_df)=24316
# using right fill, i=23947, len(eda_df)=24316
# using right fill, i=23948, len(eda_df)=24316
# using right fill, i=23949, len(eda_df)=24316
# using right fill, i=23950, len(eda_df)=24316
# using right fill, i=23951, len(eda_df)=24316
# using right fill, i=23952, len(eda_df)=24316
# using right fill, i=23953, len(eda_df)=24316
# using right fill, i=23954, len(eda_df)=24316
# using right fill, i=23955, len(eda_df)=24316
# using right fill, i=23956, len(eda_df)=24316
# using right fill, i=23957, len(eda_df)=24316
# using right fill, i=23958, len(eda_df)=24316
# using right fill, i=23959, len(eda_df)=24316
# using right fill, i=23960, len(eda_df)=24316
# using right fill, i=23961, len(eda_df)=24316
# using right fill, i=23962, len(eda_df)=24316
# using right fill, i=23963, len(eda_df)=24316
# using right fill, i=23964, len(eda_df)=24316
# using right fill, i=23965, len(eda_df)=24316
# using right fill, i=23966, len(eda_df)=24316
# using right fill, i=23967, len(eda_df)=24316
# using right fill, i=23968, len(eda_df)=24316
# using right fill, i=23969, len(eda_df)=24316
# using right fill, i=23970, len(eda_df)=24316
# using right fill, i=23971, len(eda_df)=24316
# using right fill, i=23972, len(eda_df)=24316
# using right fill, i=23973, len(eda_df)=24316
# using right fill, i=23974, len(eda_df)=24316
# using right fill, i=23975, len(eda_df)=24316
# using right fill, i=23976, len(eda_df)=24316
# using right fill, i=23977, len(eda_df)=24316
# using right fill, i=23978, len(eda_df)=24316
# using right fill, i=23979, len(eda_df)=24316
# using right fill, i=23980, len(eda_df)=24316
# using right fill, i=23981, len(eda_df)=24316
# using right fill, i=23982, len(eda_df)=24316
# using right fill, i=23983, len(eda_df)=24316
# using right fill, i=23984, len(eda_df)=24316
# using right fill, i=23985, len(eda_df)=24316
# using right fill, i=23986, len(eda_df)=24316
# using right fill, i=23987, len(eda_df)=24316
# using right fill, i=23988, len(eda_df)=24316
# using right fill, i=23989, len(eda_df)=24316
# using right fill, i=23990, len(eda_df)=24316
# using right fill, i=23991, len(eda_df)=24316
# using right fill, i=23992, len(eda_df)=24316
# using right fill, i=23993, len(eda_df)=24316
# using right fill, i=23994, len(eda_df)=24316
# using right fill, i=23995, len(eda_df)=24316
# using right fill, i=23996, len(eda_df)=24316
# using right fill, i=23997, len(eda_df)=24316
# using right fill, i=23998, len(eda_df)=24316
# using right fill, i=23999, len(eda_df)=24316
# using right fill, i=24000, len(eda_df)=24316
# using right fill, i=24001, len(eda_df)=24316
# using right fill, i=24002, len(eda_df)=24316
# using right fill, i=24003, len(eda_df)=24316
# using right fill, i=24004, len(eda_df)=24316
# using right fill, i=24005, len(eda_df)=24316
# using right fill, i=24006, len(eda_df)=24316
# using right fill, i=24007, len(eda_df)=24316
# using right fill, i=24008, len(eda_df)=24316
# using right fill, i=24009, len(eda_df)=24316
# using right fill, i=24010, len(eda_df)=24316
# using right fill, i=24011, len(eda_df)=24316
# using right fill, i=24012, len(eda_df)=24316
# using right fill, i=24013, len(eda_df)=24316
# using right fill, i=24014, len(eda_df)=24316
# using right fill, i=24015, len(eda_df)=24316
# using right fill, i=24016, len(eda_df)=24316
# using right fill, i=24017, len(eda_df)=24316
# using right fill, i=24018, len(eda_df)=24316
# using right fill, i=24019, len(eda_df)=24316
# using right fill, i=24020, len(eda_df)=24316
# using right fill, i=24021, len(eda_df)=24316
# using right fill, i=24022, len(eda_df)=24316
# using right fill, i=24023, len(eda_df)=24316
# using right fill, i=24024, len(eda_df)=24316
# using right fill, i=24025, len(eda_df)=24316
# using right fill, i=24026, len(eda_df)=24316
# using right fill, i=24027, len(eda_df)=24316
# using right fill, i=24028, len(eda_df)=24316
# using right fill, i=24029, len(eda_df)=24316
# using right fill, i=24030, len(eda_df)=24316
# using right fill, i=24031, len(eda_df)=24316
# using right fill, i=24032, len(eda_df)=24316
# using right fill, i=24033, len(eda_df)=24316
# using right fill, i=24034, len(eda_df)=24316
# using right fill, i=24035, len(eda_df)=24316
# using right fill, i=24036, len(eda_df)=24316
# using right fill, i=24037, len(eda_df)=24316
# using right fill, i=24038, len(eda_df)=24316
# using right fill, i=24039, len(eda_df)=24316
# using right fill, i=24040, len(eda_df)=24316
# using right fill, i=24041, len(eda_df)=24316
# using right fill, i=24042, len(eda_df)=24316
# using right fill, i=24043, len(eda_df)=24316
# using right fill, i=24044, len(eda_df)=24316
# using right fill, i=24045, len(eda_df)=24316
# using right fill, i=24046, len(eda_df)=24316
# using right fill, i=24047, len(eda_df)=24316
# using right fill, i=24048, len(eda_df)=24316
# using right fill, i=24049, len(eda_df)=24316
# using right fill, i=24050, len(eda_df)=24316
# using right fill, i=24051, len(eda_df)=24316
# using right fill, i=24052, len(eda_df)=24316
# using right fill, i=24053, len(eda_df)=24316
# using right fill, i=24054, len(eda_df)=24316
# using right fill, i=24055, len(eda_df)=24316
# using right fill, i=24056, len(eda_df)=24316
# using right fill, i=24057, len(eda_df)=24316
# using right fill, i=24058, len(eda_df)=24316
# using right fill, i=24059, len(eda_df)=24316
# using right fill, i=24060, len(eda_df)=24316
# using right fill, i=24061, len(eda_df)=24316
# using right fill, i=24062, len(eda_df)=24316
# using right fill, i=24063, len(eda_df)=24316
# using right fill, i=24064, len(eda_df)=24316
# using right fill, i=24065, len(eda_df)=24316
# using right fill, i=24066, len(eda_df)=24316
# using right fill, i=24067, len(eda_df)=24316
# using right fill, i=24068, len(eda_df)=24316
# using right fill, i=24069, len(eda_df)=24316
# using right fill, i=24070, len(eda_df)=24316
# using right fill, i=24071, len(eda_df)=24316
# using right fill, i=24072, len(eda_df)=24316
# using right fill, i=24073, len(eda_df)=24316
# using right fill, i=24074, len(eda_df)=24316
# using right fill, i=24075, len(eda_df)=24316
# 6560 examples are stress/no-stress; whole dataset has 24075 examples
# working on subject S3
# Loaded data
# label shape (4545100, 2)
# EDA shape (25972, 2)
# using left fill, i=1
# using left fill, i=2
# using left fill, i=3
# using left fill, i=4
# using left fill, i=5
# using left fill, i=6
# using left fill, i=7
# using left fill, i=8
# using left fill, i=9
# using left fill, i=10
# using left fill, i=11
# using left fill, i=12
# using left fill, i=13
# using left fill, i=14
# using left fill, i=15
# using left fill, i=16
# using left fill, i=17
# using left fill, i=18
# using left fill, i=19
# using left fill, i=20
# using left fill, i=21
# using left fill, i=22
# using left fill, i=23
# using left fill, i=24
# using left fill, i=25
# using left fill, i=26
# using left fill, i=27
# using left fill, i=28
# using left fill, i=29
# using left fill, i=30
# using left fill, i=31
# using left fill, i=32
# using left fill, i=33
# using left fill, i=34
# using left fill, i=35
# using left fill, i=36
# using left fill, i=37
# using left fill, i=38
# using left fill, i=39
# using left fill, i=40
# using left fill, i=41
# using left fill, i=42
# using left fill, i=43
# using left fill, i=44
# using left fill, i=45
# using left fill, i=46
# using left fill, i=47
# using left fill, i=48
# using left fill, i=49
# using left fill, i=50
# using left fill, i=51
# using left fill, i=52
# using left fill, i=53
# using left fill, i=54
# using left fill, i=55
# using left fill, i=56
# using left fill, i=57
# using left fill, i=58
# using left fill, i=59
# using left fill, i=60
# using left fill, i=61
# using left fill, i=62
# using left fill, i=63
# using left fill, i=64
# using left fill, i=65
# using left fill, i=66
# using left fill, i=67
# using left fill, i=68
# using left fill, i=69
# using left fill, i=70
# using left fill, i=71
# using left fill, i=72
# using left fill, i=73
# using left fill, i=74
# using left fill, i=75
# using left fill, i=76
# using left fill, i=77
# using left fill, i=78
# using left fill, i=79
# using left fill, i=80
# using left fill, i=81
# using left fill, i=82
# using left fill, i=83
# using left fill, i=84
# using left fill, i=85
# using left fill, i=86
# using left fill, i=87
# using left fill, i=88
# using left fill, i=89
# using left fill, i=90
# using left fill, i=91
# using left fill, i=92
# using left fill, i=93
# using left fill, i=94
# using left fill, i=95
# using left fill, i=96
# using left fill, i=97
# using left fill, i=98
# using left fill, i=99
# using left fill, i=100
# using left fill, i=101
# using left fill, i=102
# using left fill, i=103
# using left fill, i=104
# using left fill, i=105
# using left fill, i=106
# using left fill, i=107
# using left fill, i=108
# using left fill, i=109
# using left fill, i=110
# using left fill, i=111
# using left fill, i=112
# using left fill, i=113
# using left fill, i=114
# using left fill, i=115
# using left fill, i=116
# using left fill, i=117
# using left fill, i=118
# using left fill, i=119
# using left fill, i=120
# using left fill, i=121
# using left fill, i=122
# using left fill, i=123
# using left fill, i=124
# using left fill, i=125
# using left fill, i=126
# using left fill, i=127
# using left fill, i=128
# using left fill, i=129
# using left fill, i=130
# using left fill, i=131
# using left fill, i=132
# using left fill, i=133
# using left fill, i=134
# using left fill, i=135
# using left fill, i=136
# using left fill, i=137
# using left fill, i=138
# using left fill, i=139
# using left fill, i=140
# using left fill, i=141
# using left fill, i=142
# using left fill, i=143
# using left fill, i=144
# using left fill, i=145
# using left fill, i=146
# using left fill, i=147
# using left fill, i=148
# using left fill, i=149
# using left fill, i=150
# using left fill, i=151
# using left fill, i=152
# using left fill, i=153
# using left fill, i=154
# using left fill, i=155
# using left fill, i=156
# using left fill, i=157
# using left fill, i=158
# using left fill, i=159
# using left fill, i=160
# using left fill, i=161
# using left fill, i=162
# using left fill, i=163
# using left fill, i=164
# using left fill, i=165
# using left fill, i=166
# using left fill, i=167
# using left fill, i=168
# using left fill, i=169
# using left fill, i=170
# using left fill, i=171
# using left fill, i=172
# using left fill, i=173
# using left fill, i=174
# using left fill, i=175
# using left fill, i=176
# using left fill, i=177
# using left fill, i=178
# using left fill, i=179
# using left fill, i=180
# using left fill, i=181
# using left fill, i=182
# using left fill, i=183
# using left fill, i=184
# using left fill, i=185
# using left fill, i=186
# using left fill, i=187
# using left fill, i=188
# using left fill, i=189
# using left fill, i=190
# using left fill, i=191
# using left fill, i=192
# using left fill, i=193
# using left fill, i=194
# using left fill, i=195
# using left fill, i=196
# using left fill, i=197
# using left fill, i=198
# using left fill, i=199
# using left fill, i=200
# using left fill, i=201
# using left fill, i=202
# using left fill, i=203
# using left fill, i=204
# using left fill, i=205
# using left fill, i=206
# using left fill, i=207
# using left fill, i=208
# using left fill, i=209
# using left fill, i=210
# using left fill, i=211
# using left fill, i=212
# using left fill, i=213
# using left fill, i=214
# using left fill, i=215
# using left fill, i=216
# using left fill, i=217
# using left fill, i=218
# using left fill, i=219
# using left fill, i=220
# using left fill, i=221
# using left fill, i=222
# using left fill, i=223
# using left fill, i=224
# using left fill, i=225
# using left fill, i=226
# using left fill, i=227
# using left fill, i=228
# using left fill, i=229
# using left fill, i=230
# using left fill, i=231
# using left fill, i=232
# using left fill, i=233
# using left fill, i=234
# using left fill, i=235
# using left fill, i=236
# using left fill, i=237
# using left fill, i=238
# using left fill, i=239
# using right fill, i=25492, len(eda_df)=25972
# using right fill, i=25493, len(eda_df)=25972
# using right fill, i=25494, len(eda_df)=25972
# using right fill, i=25495, len(eda_df)=25972
# using right fill, i=25496, len(eda_df)=25972
# using right fill, i=25497, len(eda_df)=25972
# using right fill, i=25498, len(eda_df)=25972
# using right fill, i=25499, len(eda_df)=25972
# using right fill, i=25500, len(eda_df)=25972
# using right fill, i=25501, len(eda_df)=25972
# using right fill, i=25502, len(eda_df)=25972
# using right fill, i=25503, len(eda_df)=25972
# using right fill, i=25504, len(eda_df)=25972
# using right fill, i=25505, len(eda_df)=25972
# using right fill, i=25506, len(eda_df)=25972
# using right fill, i=25507, len(eda_df)=25972
# using right fill, i=25508, len(eda_df)=25972
# using right fill, i=25509, len(eda_df)=25972
# using right fill, i=25510, len(eda_df)=25972
# using right fill, i=25511, len(eda_df)=25972
# using right fill, i=25512, len(eda_df)=25972
# using right fill, i=25513, len(eda_df)=25972
# using right fill, i=25514, len(eda_df)=25972
# using right fill, i=25515, len(eda_df)=25972
# using right fill, i=25516, len(eda_df)=25972
# using right fill, i=25517, len(eda_df)=25972
# using right fill, i=25518, len(eda_df)=25972
# using right fill, i=25519, len(eda_df)=25972
# using right fill, i=25520, len(eda_df)=25972
# using right fill, i=25521, len(eda_df)=25972
# using right fill, i=25522, len(eda_df)=25972
# using right fill, i=25523, len(eda_df)=25972
# using right fill, i=25524, len(eda_df)=25972
# using right fill, i=25525, len(eda_df)=25972
# using right fill, i=25526, len(eda_df)=25972
# using right fill, i=25527, len(eda_df)=25972
# using right fill, i=25528, len(eda_df)=25972
# using right fill, i=25529, len(eda_df)=25972
# using right fill, i=25530, len(eda_df)=25972
# using right fill, i=25531, len(eda_df)=25972
# using right fill, i=25532, len(eda_df)=25972
# using right fill, i=25533, len(eda_df)=25972
# using right fill, i=25534, len(eda_df)=25972
# using right fill, i=25535, len(eda_df)=25972
# using right fill, i=25536, len(eda_df)=25972
# using right fill, i=25537, len(eda_df)=25972
# using right fill, i=25538, len(eda_df)=25972
# using right fill, i=25539, len(eda_df)=25972
# using right fill, i=25540, len(eda_df)=25972
# using right fill, i=25541, len(eda_df)=25972
# using right fill, i=25542, len(eda_df)=25972
# using right fill, i=25543, len(eda_df)=25972
# using right fill, i=25544, len(eda_df)=25972
# using right fill, i=25545, len(eda_df)=25972
# using right fill, i=25546, len(eda_df)=25972
# using right fill, i=25547, len(eda_df)=25972
# using right fill, i=25548, len(eda_df)=25972
# using right fill, i=25549, len(eda_df)=25972
# using right fill, i=25550, len(eda_df)=25972
# using right fill, i=25551, len(eda_df)=25972
# using right fill, i=25552, len(eda_df)=25972
# using right fill, i=25553, len(eda_df)=25972
# using right fill, i=25554, len(eda_df)=25972
# using right fill, i=25555, len(eda_df)=25972
# using right fill, i=25556, len(eda_df)=25972
# using right fill, i=25557, len(eda_df)=25972
# using right fill, i=25558, len(eda_df)=25972
# using right fill, i=25559, len(eda_df)=25972
# using right fill, i=25560, len(eda_df)=25972
# using right fill, i=25561, len(eda_df)=25972
# using right fill, i=25562, len(eda_df)=25972
# using right fill, i=25563, len(eda_df)=25972
# using right fill, i=25564, len(eda_df)=25972
# using right fill, i=25565, len(eda_df)=25972
# using right fill, i=25566, len(eda_df)=25972
# using right fill, i=25567, len(eda_df)=25972
# using right fill, i=25568, len(eda_df)=25972
# using right fill, i=25569, len(eda_df)=25972
# using right fill, i=25570, len(eda_df)=25972
# using right fill, i=25571, len(eda_df)=25972
# using right fill, i=25572, len(eda_df)=25972
# using right fill, i=25573, len(eda_df)=25972
# using right fill, i=25574, len(eda_df)=25972
# using right fill, i=25575, len(eda_df)=25972
# using right fill, i=25576, len(eda_df)=25972
# using right fill, i=25577, len(eda_df)=25972
# using right fill, i=25578, len(eda_df)=25972
# using right fill, i=25579, len(eda_df)=25972
# using right fill, i=25580, len(eda_df)=25972
# using right fill, i=25581, len(eda_df)=25972
# using right fill, i=25582, len(eda_df)=25972
# using right fill, i=25583, len(eda_df)=25972
# using right fill, i=25584, len(eda_df)=25972
# using right fill, i=25585, len(eda_df)=25972
# using right fill, i=25586, len(eda_df)=25972
# using right fill, i=25587, len(eda_df)=25972
# using right fill, i=25588, len(eda_df)=25972
# using right fill, i=25589, len(eda_df)=25972
# using right fill, i=25590, len(eda_df)=25972
# using right fill, i=25591, len(eda_df)=25972
# using right fill, i=25592, len(eda_df)=25972
# using right fill, i=25593, len(eda_df)=25972
# using right fill, i=25594, len(eda_df)=25972
# using right fill, i=25595, len(eda_df)=25972
# using right fill, i=25596, len(eda_df)=25972
# using right fill, i=25597, len(eda_df)=25972
# using right fill, i=25598, len(eda_df)=25972
# using right fill, i=25599, len(eda_df)=25972
# using right fill, i=25600, len(eda_df)=25972
# using right fill, i=25601, len(eda_df)=25972
# using right fill, i=25602, len(eda_df)=25972
# using right fill, i=25603, len(eda_df)=25972
# using right fill, i=25604, len(eda_df)=25972
# using right fill, i=25605, len(eda_df)=25972
# using right fill, i=25606, len(eda_df)=25972
# using right fill, i=25607, len(eda_df)=25972
# using right fill, i=25608, len(eda_df)=25972
# using right fill, i=25609, len(eda_df)=25972
# using right fill, i=25610, len(eda_df)=25972
# using right fill, i=25611, len(eda_df)=25972
# using right fill, i=25612, len(eda_df)=25972
# using right fill, i=25613, len(eda_df)=25972
# using right fill, i=25614, len(eda_df)=25972
# using right fill, i=25615, len(eda_df)=25972
# using right fill, i=25616, len(eda_df)=25972
# using right fill, i=25617, len(eda_df)=25972
# using right fill, i=25618, len(eda_df)=25972
# using right fill, i=25619, len(eda_df)=25972
# using right fill, i=25620, len(eda_df)=25972
# using right fill, i=25621, len(eda_df)=25972
# using right fill, i=25622, len(eda_df)=25972
# using right fill, i=25623, len(eda_df)=25972
# using right fill, i=25624, len(eda_df)=25972
# using right fill, i=25625, len(eda_df)=25972
# using right fill, i=25626, len(eda_df)=25972
# using right fill, i=25627, len(eda_df)=25972
# using right fill, i=25628, len(eda_df)=25972
# using right fill, i=25629, len(eda_df)=25972
# using right fill, i=25630, len(eda_df)=25972
# using right fill, i=25631, len(eda_df)=25972
# using right fill, i=25632, len(eda_df)=25972
# using right fill, i=25633, len(eda_df)=25972
# using right fill, i=25634, len(eda_df)=25972
# using right fill, i=25635, len(eda_df)=25972
# using right fill, i=25636, len(eda_df)=25972
# using right fill, i=25637, len(eda_df)=25972
# using right fill, i=25638, len(eda_df)=25972
# using right fill, i=25639, len(eda_df)=25972
# using right fill, i=25640, len(eda_df)=25972
# using right fill, i=25641, len(eda_df)=25972
# using right fill, i=25642, len(eda_df)=25972
# using right fill, i=25643, len(eda_df)=25972
# using right fill, i=25644, len(eda_df)=25972
# using right fill, i=25645, len(eda_df)=25972
# using right fill, i=25646, len(eda_df)=25972
# using right fill, i=25647, len(eda_df)=25972
# using right fill, i=25648, len(eda_df)=25972
# using right fill, i=25649, len(eda_df)=25972
# using right fill, i=25650, len(eda_df)=25972
# using right fill, i=25651, len(eda_df)=25972
# using right fill, i=25652, len(eda_df)=25972
# using right fill, i=25653, len(eda_df)=25972
# using right fill, i=25654, len(eda_df)=25972
# using right fill, i=25655, len(eda_df)=25972
# using right fill, i=25656, len(eda_df)=25972
# using right fill, i=25657, len(eda_df)=25972
# using right fill, i=25658, len(eda_df)=25972
# using right fill, i=25659, len(eda_df)=25972
# using right fill, i=25660, len(eda_df)=25972
# using right fill, i=25661, len(eda_df)=25972
# using right fill, i=25662, len(eda_df)=25972
# using right fill, i=25663, len(eda_df)=25972
# using right fill, i=25664, len(eda_df)=25972
# using right fill, i=25665, len(eda_df)=25972
# using right fill, i=25666, len(eda_df)=25972
# using right fill, i=25667, len(eda_df)=25972
# using right fill, i=25668, len(eda_df)=25972
# using right fill, i=25669, len(eda_df)=25972
# using right fill, i=25670, len(eda_df)=25972
# using right fill, i=25671, len(eda_df)=25972
# using right fill, i=25672, len(eda_df)=25972
# using right fill, i=25673, len(eda_df)=25972
# using right fill, i=25674, len(eda_df)=25972
# using right fill, i=25675, len(eda_df)=25972
# using right fill, i=25676, len(eda_df)=25972
# using right fill, i=25677, len(eda_df)=25972
# using right fill, i=25678, len(eda_df)=25972
# using right fill, i=25679, len(eda_df)=25972
# using right fill, i=25680, len(eda_df)=25972
# using right fill, i=25681, len(eda_df)=25972
# using right fill, i=25682, len(eda_df)=25972
# using right fill, i=25683, len(eda_df)=25972
# using right fill, i=25684, len(eda_df)=25972
# using right fill, i=25685, len(eda_df)=25972
# using right fill, i=25686, len(eda_df)=25972
# using right fill, i=25687, len(eda_df)=25972
# using right fill, i=25688, len(eda_df)=25972
# using right fill, i=25689, len(eda_df)=25972
# using right fill, i=25690, len(eda_df)=25972
# using right fill, i=25691, len(eda_df)=25972
# using right fill, i=25692, len(eda_df)=25972
# using right fill, i=25693, len(eda_df)=25972
# using right fill, i=25694, len(eda_df)=25972
# using right fill, i=25695, len(eda_df)=25972
# using right fill, i=25696, len(eda_df)=25972
# using right fill, i=25697, len(eda_df)=25972
# using right fill, i=25698, len(eda_df)=25972
# using right fill, i=25699, len(eda_df)=25972
# using right fill, i=25700, len(eda_df)=25972
# using right fill, i=25701, len(eda_df)=25972
# using right fill, i=25702, len(eda_df)=25972
# using right fill, i=25703, len(eda_df)=25972
# using right fill, i=25704, len(eda_df)=25972
# using right fill, i=25705, len(eda_df)=25972
# using right fill, i=25706, len(eda_df)=25972
# using right fill, i=25707, len(eda_df)=25972
# using right fill, i=25708, len(eda_df)=25972
# using right fill, i=25709, len(eda_df)=25972
# using right fill, i=25710, len(eda_df)=25972
# ...
# using left fill, i=14
# using left fill, i=15
# using left fill, i=16
# using left fill, i=17
# using left fill, i=18
# using left fill, i=19
# using left fill, i=20
# using left fill, i=21
# using left fill, i=22
# using left fill, i=23
# using left fill, i=24
# using left fill, i=25
# using left fill, i=26
# using left fill, i=27
# using left fill, i=28
# using left fill, i=29
# using left fill, i=30
# using left fill, i=31
# using left fill, i=32
# using left fill, i=33
# using left fill, i=34
# using left fill, i=35
# using left fill, i=36
# using left fill, i=37
# using left fill, i=38
# using left fill, i=39
# using left fill, i=40
# using left fill, i=41
# using left fill, i=42
# using left fill, i=43
# using left fill, i=44
# using left fill, i=45
# using left fill, i=46
# using left fill, i=47
# using left fill, i=48
# using left fill, i=49
# using left fill, i=50
# using left fill, i=51
# using left fill, i=52
# using left fill, i=53
# using left fill, i=54
# using left fill, i=55
# using left fill, i=56
# using left fill, i=57
# using left fill, i=58
# using left fill, i=59
# using left fill, i=60
# using left fill, i=61
# using left fill, i=62
# using left fill, i=63
# using left fill, i=64
# using left fill, i=65
# using left fill, i=66
# using left fill, i=67
# using left fill, i=68
# using left fill, i=69
# using left fill, i=70
# using left fill, i=71
# using left fill, i=72
# using left fill, i=73
# using left fill, i=74
# using left fill, i=75
# using left fill, i=76
# using left fill, i=77
# using left fill, i=78
# using left fill, i=79
# using left fill, i=80
# using left fill, i=81
# using left fill, i=82
# using left fill, i=83
# using left fill, i=84
# using left fill, i=85
# using left fill, i=86
# using left fill, i=87
# using left fill, i=88
# using left fill, i=89
# using left fill, i=90
# using left fill, i=91
# using left fill, i=92
# using left fill, i=93
# using left fill, i=94
# using left fill, i=95
# using left fill, i=96
# using left fill, i=97
# using left fill, i=98
# using left fill, i=99
# using left fill, i=100
# using left fill, i=101
# using left fill, i=102
# using left fill, i=103
# using left fill, i=104
# using left fill, i=105
# using left fill, i=106
# using left fill, i=107
# using left fill, i=108
# using left fill, i=109
# using left fill, i=110
# using left fill, i=111
# using left fill, i=112
# using left fill, i=113
# using left fill, i=114
# using left fill, i=115
# using left fill, i=116
# using left fill, i=117
# using left fill, i=118
# using left fill, i=119
# using left fill, i=120
# using left fill, i=121
# using left fill, i=122
# using left fill, i=123
# using left fill, i=124
# using left fill, i=125
# using left fill, i=126
# using left fill, i=127
# using left fill, i=128
# using left fill, i=129
# using left fill, i=130
# using left fill, i=131
# using left fill, i=132
# using left fill, i=133
# using left fill, i=134
# using left fill, i=135
# using left fill, i=136
# using left fill, i=137
# using left fill, i=138
# using left fill, i=139
# using left fill, i=140
# using left fill, i=141
# using left fill, i=142
# using left fill, i=143
# using left fill, i=144
# using left fill, i=145
# using left fill, i=146
# using left fill, i=147
# using left fill, i=148
# using left fill, i=149
# using left fill, i=150
# using left fill, i=151
# using left fill, i=152
# using left fill, i=153
# using left fill, i=154
# using left fill, i=155
# using left fill, i=156
# using left fill, i=157
# using left fill, i=158
# using left fill, i=159
# using left fill, i=160
# using left fill, i=161
# using left fill, i=162
# using left fill, i=163
# using left fill, i=164
# using left fill, i=165
# using left fill, i=166
# using left fill, i=167
# using left fill, i=168
# using left fill, i=169
# using left fill, i=170
# using left fill, i=171
# using left fill, i=172
# using left fill, i=173
# using left fill, i=174
# using left fill, i=175
# using left fill, i=176
# using left fill, i=177
# using left fill, i=178
# using left fill, i=179
# using left fill, i=180
# using left fill, i=181
# using left fill, i=182
# using left fill, i=183
# using left fill, i=184
# using left fill, i=185
# using left fill, i=186
# using left fill, i=187
# using left fill, i=188
# using left fill, i=189
# using left fill, i=190
# using left fill, i=191
# using left fill, i=192
# using left fill, i=193
# using left fill, i=194
# using left fill, i=195
# using left fill, i=196
# using left fill, i=197
# using left fill, i=198
# using left fill, i=199
# using left fill, i=200
# using left fill, i=201
# using left fill, i=202
# using left fill, i=203
# using left fill, i=204
# using left fill, i=205
# using left fill, i=206
# using left fill, i=207
# using left fill, i=208
# using left fill, i=209
# using left fill, i=210
# using left fill, i=211
# using left fill, i=212
# using left fill, i=213
# using left fill, i=214
# using left fill, i=215
# using left fill, i=216
# using left fill, i=217
# using left fill, i=218
# using left fill, i=219
# using left fill, i=220
# using left fill, i=221
# using left fill, i=222
# using left fill, i=223
# using left fill, i=224
# using left fill, i=225
# using left fill, i=226
# using left fill, i=227
# using left fill, i=228
# using left fill, i=229
# using left fill, i=230
# using left fill, i=231
# using left fill, i=232
# using left fill, i=233
# using left fill, i=234
# using left fill, i=235
# using left fill, i=236
# using left fill, i=237
# using left fill, i=238
# using left fill, i=239
# using right fill, i=20528, len(eda_df)=21008
# using right fill, i=20529, len(eda_df)=21008
# using right fill, i=20530, len(eda_df)=21008
# using right fill, i=20531, len(eda_df)=21008
# using right fill, i=20532, len(eda_df)=21008
# using right fill, i=20533, len(eda_df)=21008
# using right fill, i=20534, len(eda_df)=21008
# using right fill, i=20535, len(eda_df)=21008
# using right fill, i=20536, len(eda_df)=21008
# using right fill, i=20537, len(eda_df)=21008
# using right fill, i=20538, len(eda_df)=21008
# using right fill, i=20539, len(eda_df)=21008
# using right fill, i=20540, len(eda_df)=21008
# using right fill, i=20541, len(eda_df)=21008
# using right fill, i=20542, len(eda_df)=21008
# using right fill, i=20543, len(eda_df)=21008
# using right fill, i=20544, len(eda_df)=21008
# using right fill, i=20545, len(eda_df)=21008
# using right fill, i=20546, len(eda_df)=21008
# using right fill, i=20547, len(eda_df)=21008
# using right fill, i=20548, len(eda_df)=21008
# using right fill, i=20549, len(eda_df)=21008
# using right fill, i=20550, len(eda_df)=21008
# using right fill, i=20551, len(eda_df)=21008
# using right fill, i=20552, len(eda_df)=21008
# using right fill, i=20553, len(eda_df)=21008
# using right fill, i=20554, len(eda_df)=21008
# using right fill, i=20555, len(eda_df)=21008
# using right fill, i=20556, len(eda_df)=21008
# using right fill, i=20557, len(eda_df)=21008
# using right fill, i=20558, len(eda_df)=21008
# using right fill, i=20559, len(eda_df)=21008
# using right fill, i=20560, len(eda_df)=21008
# using right fill, i=20561, len(eda_df)=21008
# using right fill, i=20562, len(eda_df)=21008
# using right fill, i=20563, len(eda_df)=21008
# using right fill, i=20564, len(eda_df)=21008
# using right fill, i=20565, len(eda_df)=21008
# using right fill, i=20566, len(eda_df)=21008
# using right fill, i=20567, len(eda_df)=21008
# using right fill, i=20568, len(eda_df)=21008
# using right fill, i=20569, len(eda_df)=21008
# using right fill, i=20570, len(eda_df)=21008
# using right fill, i=20571, len(eda_df)=21008
# using right fill, i=20572, len(eda_df)=21008
# using right fill, i=20573, len(eda_df)=21008
# using right fill, i=20574, len(eda_df)=21008
# using right fill, i=20575, len(eda_df)=21008
# using right fill, i=20576, len(eda_df)=21008
# using right fill, i=20577, len(eda_df)=21008
# using right fill, i=20578, len(eda_df)=21008
# using right fill, i=20579, len(eda_df)=21008
# using right fill, i=20580, len(eda_df)=21008
# using right fill, i=20581, len(eda_df)=21008
# using right fill, i=20582, len(eda_df)=21008
# using right fill, i=20583, len(eda_df)=21008
# using right fill, i=20584, len(eda_df)=21008
# using right fill, i=20585, len(eda_df)=21008
# using right fill, i=20586, len(eda_df)=21008
# using right fill, i=20587, len(eda_df)=21008
# using right fill, i=20588, len(eda_df)=21008
# using right fill, i=20589, len(eda_df)=21008
# using right fill, i=20590, len(eda_df)=21008
# using right fill, i=20591, len(eda_df)=21008
# using right fill, i=20592, len(eda_df)=21008
# using right fill, i=20593, len(eda_df)=21008
# using right fill, i=20594, len(eda_df)=21008
# using right fill, i=20595, len(eda_df)=21008
# using right fill, i=20596, len(eda_df)=21008
# using right fill, i=20597, len(eda_df)=21008
# using right fill, i=20598, len(eda_df)=21008
# using right fill, i=20599, len(eda_df)=21008
# using right fill, i=20600, len(eda_df)=21008
# using right fill, i=20601, len(eda_df)=21008
# using right fill, i=20602, len(eda_df)=21008
# using right fill, i=20603, len(eda_df)=21008
# using right fill, i=20604, len(eda_df)=21008
# using right fill, i=20605, len(eda_df)=21008
# using right fill, i=20606, len(eda_df)=21008
# using right fill, i=20607, len(eda_df)=21008
# using right fill, i=20608, len(eda_df)=21008
# using right fill, i=20609, len(eda_df)=21008
# using right fill, i=20610, len(eda_df)=21008
# using right fill, i=20611, len(eda_df)=21008
# using right fill, i=20612, len(eda_df)=21008
# using right fill, i=20613, len(eda_df)=21008
# using right fill, i=20614, len(eda_df)=21008
# using right fill, i=20615, len(eda_df)=21008
# using right fill, i=20616, len(eda_df)=21008
# using right fill, i=20617, len(eda_df)=21008
# using right fill, i=20618, len(eda_df)=21008
# using right fill, i=20619, len(eda_df)=21008
# using right fill, i=20620, len(eda_df)=21008
# using right fill, i=20621, len(eda_df)=21008
# using right fill, i=20622, len(eda_df)=21008
# using right fill, i=20623, len(eda_df)=21008
# using right fill, i=20624, len(eda_df)=21008
# using right fill, i=20625, len(eda_df)=21008
# using right fill, i=20626, len(eda_df)=21008
# using right fill, i=20627, len(eda_df)=21008
# using right fill, i=20628, len(eda_df)=21008
# using right fill, i=20629, len(eda_df)=21008
# using right fill, i=20630, len(eda_df)=21008
# using right fill, i=20631, len(eda_df)=21008
# using right fill, i=20632, len(eda_df)=21008
# using right fill, i=20633, len(eda_df)=21008
# using right fill, i=20634, len(eda_df)=21008
# using right fill, i=20635, len(eda_df)=21008
# using right fill, i=20636, len(eda_df)=21008
# using right fill, i=20637, len(eda_df)=21008
# using right fill, i=20638, len(eda_df)=21008
# using right fill, i=20639, len(eda_df)=21008
# using right fill, i=20640, len(eda_df)=21008
# using right fill, i=20641, len(eda_df)=21008
# using right fill, i=20642, len(eda_df)=21008
# using right fill, i=20643, len(eda_df)=21008
# using right fill, i=20644, len(eda_df)=21008
# using right fill, i=20645, len(eda_df)=21008
# using right fill, i=20646, len(eda_df)=21008
# using right fill, i=20647, len(eda_df)=21008
# using right fill, i=20648, len(eda_df)=21008
# using right fill, i=20649, len(eda_df)=21008
# using right fill, i=20650, len(eda_df)=21008
# using right fill, i=20651, len(eda_df)=21008
# using right fill, i=20652, len(eda_df)=21008
# using right fill, i=20653, len(eda_df)=21008
# using right fill, i=20654, len(eda_df)=21008
# using right fill, i=20655, len(eda_df)=21008
# using right fill, i=20656, len(eda_df)=21008
# using right fill, i=20657, len(eda_df)=21008
# using right fill, i=20658, len(eda_df)=21008
# using right fill, i=20659, len(eda_df)=21008
# using right fill, i=20660, len(eda_df)=21008
# using right fill, i=20661, len(eda_df)=21008
# using right fill, i=20662, len(eda_df)=21008
# using right fill, i=20663, len(eda_df)=21008
# using right fill, i=20664, len(eda_df)=21008
# using right fill, i=20665, len(eda_df)=21008
# using right fill, i=20666, len(eda_df)=21008
# using right fill, i=20667, len(eda_df)=21008
# using right fill, i=20668, len(eda_df)=21008
# using right fill, i=20669, len(eda_df)=21008
# using right fill, i=20670, len(eda_df)=21008
# using right fill, i=20671, len(eda_df)=21008
# using right fill, i=20672, len(eda_df)=21008
# using right fill, i=20673, len(eda_df)=21008
# using right fill, i=20674, len(eda_df)=21008
# using right fill, i=20675, len(eda_df)=21008
# using right fill, i=20676, len(eda_df)=21008
# using right fill, i=20677, len(eda_df)=21008
# using right fill, i=20678, len(eda_df)=21008
# using right fill, i=20679, len(eda_df)=21008
# using right fill, i=20680, len(eda_df)=21008
# using right fill, i=20681, len(eda_df)=21008
# using right fill, i=20682, len(eda_df)=21008
# using right fill, i=20683, len(eda_df)=21008
# using right fill, i=20684, len(eda_df)=21008
# using right fill, i=20685, len(eda_df)=21008
# using right fill, i=20686, len(eda_df)=21008
# using right fill, i=20687, len(eda_df)=21008
# using right fill, i=20688, len(eda_df)=21008
# using right fill, i=20689, len(eda_df)=21008
# using right fill, i=20690, len(eda_df)=21008
# using right fill, i=20691, len(eda_df)=21008
# using right fill, i=20692, len(eda_df)=21008
# using right fill, i=20693, len(eda_df)=21008
# using right fill, i=20694, len(eda_df)=21008
# using right fill, i=20695, len(eda_df)=21008
# using right fill, i=20696, len(eda_df)=21008
# using right fill, i=20697, len(eda_df)=21008
# using right fill, i=20698, len(eda_df)=21008
# using right fill, i=20699, len(eda_df)=21008
# using right fill, i=20700, len(eda_df)=21008
# using right fill, i=20701, len(eda_df)=21008
# using right fill, i=20702, len(eda_df)=21008
# using right fill, i=20703, len(eda_df)=21008
# using right fill, i=20704, len(eda_df)=21008
# using right fill, i=20705, len(eda_df)=21008
# using right fill, i=20706, len(eda_df)=21008
# using right fill, i=20707, len(eda_df)=21008
# using right fill, i=20708, len(eda_df)=21008
# using right fill, i=20709, len(eda_df)=21008
# using right fill, i=20710, len(eda_df)=21008
# using right fill, i=20711, len(eda_df)=21008
# using right fill, i=20712, len(eda_df)=21008
# using right fill, i=20713, len(eda_df)=21008
# using right fill, i=20714, len(eda_df)=21008
# using right fill, i=20715, len(eda_df)=21008
# using right fill, i=20716, len(eda_df)=21008
# using right fill, i=20717, len(eda_df)=21008
# using right fill, i=20718, len(eda_df)=21008
# using right fill, i=20719, len(eda_df)=21008
# using right fill, i=20720, len(eda_df)=21008
# using right fill, i=20721, len(eda_df)=21008
# using right fill, i=20722, len(eda_df)=21008
# using right fill, i=20723, len(eda_df)=21008
# using right fill, i=20724, len(eda_df)=21008
# using right fill, i=20725, len(eda_df)=21008
# using right fill, i=20726, len(eda_df)=21008
# using right fill, i=20727, len(eda_df)=21008
# using right fill, i=20728, len(eda_df)=21008
# using right fill, i=20729, len(eda_df)=21008
# using right fill, i=20730, len(eda_df)=21008
# using right fill, i=20731, len(eda_df)=21008
# using right fill, i=20732, len(eda_df)=21008
# using right fill, i=20733, len(eda_df)=21008
# using right fill, i=20734, len(eda_df)=21008
# using right fill, i=20735, len(eda_df)=21008
# using right fill, i=20736, len(eda_df)=21008
# using right fill, i=20737, len(eda_df)=21008
# using right fill, i=20738, len(eda_df)=21008
# using right fill, i=20739, len(eda_df)=21008
# using right fill, i=20740, len(eda_df)=21008
# using right fill, i=20741, len(eda_df)=21008
# using right fill, i=20742, len(eda_df)=21008
# using right fill, i=20743, len(eda_df)=21008
# using right fill, i=20744, len(eda_df)=21008
# using right fill, i=20745, len(eda_df)=21008
# using right fill, i=20746, len(eda_df)=21008
# using right fill, i=20747, len(eda_df)=21008
# using right fill, i=20748, len(eda_df)=21008
# using right fill, i=20749, len(eda_df)=21008
# using right fill, i=20750, len(eda_df)=21008
# using right fill, i=20751, len(eda_df)=21008
# using right fill, i=20752, len(eda_df)=21008
# using right fill, i=20753, len(eda_df)=21008
# using right fill, i=20754, len(eda_df)=21008
# using right fill, i=20755, len(eda_df)=21008
# using right fill, i=20756, len(eda_df)=21008
# using right fill, i=20757, len(eda_df)=21008
# using right fill, i=20758, len(eda_df)=21008
# using right fill, i=20759, len(eda_df)=21008
# using right fill, i=20760, len(eda_df)=21008
# using right fill, i=20761, len(eda_df)=21008
# using right fill, i=20762, len(eda_df)=21008
# using right fill, i=20763, len(eda_df)=21008
# using right fill, i=20764, len(eda_df)=21008
# using right fill, i=20765, len(eda_df)=21008
# using right fill, i=20766, len(eda_df)=21008
# using right fill, i=20767, len(eda_df)=21008
# 6968 examples are stress/no-stress; whole dataset has 20767 examples
